# %% [markdown]
# ### **Problem: Multiclass Classification**

# %% [markdown]
# ## **Objective: Prediction of Maternal Health Risk Levels**

# %% [markdown]
# # **Introduction**

# %% [markdown]
# Source: https://archive.ics.uci.edu/dataset/863/maternal+health+risk
#
# Data has been collected from different hospitals, community clinics, maternal health cares from the rural areas of Bangladesh through the IoT based risk monitoring system.
#
# Age, Systolic Blood Pressure as SystolicBP, Diastolic BP as DiastolicBP, Blood Sugar as BS, Body Temperature as BodyTemp, HeartRate and RiskLevel. All these are the responsible and significant risk factors for maternal mortality, that is one of the main concern of SDG of UN.
#
# Inputs:
#
# 1.Age: Age in years when a woman is pregnant.
#
# 2.SystolicBP: Upper value of Blood Pressure in mmHg, another significant attribute during pregnancy.
#
# 3.DiastolicBP: Lower value of Blood Pressure in mmHg, another significant attribute during pregnancy.
#
# 4.BS: Blood glucose levels is in terms of a molar concentration, mmol/L.
#
# 5.BodyTemp: Body temperatures as Fahrenheit.
#
# 6.HeartRate: A normal resting heart rate in beats per minute.
#
# Outputs:
#
# Risk Level: Predicted Risk Intensity Level during pregnancy considering the previous attribute; high, low, and mid risk.

# %% [markdown]
# # **1.Importing libraries and data**

# %%
# Exploratory data analysis and plotting libraries
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns
from scipy.io import arff
import warnings
warnings.simplefilter("ignore")

# Feature Selection
import mlxtend
from mlxtend.feature_selection import ExhaustiveFeatureSelector as EFS
from mlxtend.feature_selection import SequentialFeatureSelector as SFS

# Models from Scikit-Learn
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier, plot_tree
from xgboost import XGBClassifier

# Deep Learning
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# Model evaluations 
from sklearn import metrics
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, RocCurveDisplay 
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import classification_report, f1_score, precision_score, recall_score, average_precision_score

from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.model_selection import train_test_split, cross_val_score

from sklearn.pipeline import make_pipeline
from sklearn.pipeline import Pipeline
from sklearn import preprocessing
from sklearn.preprocessing import scale
from sklearn.preprocessing import StandardScaler

# %%
# For fixing random_state parameters
seed = 20

# %%
df = pd.read_csv("Maternal Health Risk Data Set.csv")
o_df = df.copy()
df
# Out:
#       Age  SystolicBP  DiastolicBP    BS  BodyTemp  HeartRate  RiskLevel
# 0      25         130           80  15.0      98.0         86  high risk
# 1      35         140           90  13.0      98.0         70  high risk
# 2      29          90           70   8.0     100.0         80  high risk
# 3      30         140           85   7.0      98.0         70  high risk
# 4      35         120           60   6.1      98.0         76   low risk
# ...   ...         ...          ...   ...       ...        ...        ...
# 1009   22         120           60  15.0      98.0         80  high risk
# 1010   55         120           90  18.0      98.0         60  high risk
# 1011   35          85           60  19.0      98.0         86  high risk
# 1012   43         120           90  18.0      98.0         70  high risk
# 1013   32         120           65   6.0     101.0         76   mid risk
#
# [1014 rows x 7 columns]

# %% [markdown]
# # **2.Exploratory data analysis**

# %% [markdown]
# #### **2.1.General information about dtypes and null values**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1014 entries, 0 to 1013
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Age          1014 non-null   int64
#  1   SystolicBP   1014 non-null   int64
#  2   DiastolicBP  1014 non-null   int64
#  3   BS           1014 non-null   float64
#  4   BodyTemp     1014 non-null   float64
#  5   HeartRate    1014 non-null   int64
#  6   RiskLevel    1014 non-null   object
# dtypes: float64(2), int64(4), object(1)
# memory usage: 55.6+ KB

# %% [markdown]
# #### **2.2.Number of observations and features**

# %%
df.shape
# Out:
# (1014, 7)

# %% [markdown]
# #### **2.3.Missing values**

# %%
df.isna().sum()
# Out:
# Age            0
# SystolicBP     0
# DiastolicBP    0
# BS             0
# BodyTemp       0
# HeartRate      0
# RiskLevel      0
# dtype: int64

# %% [markdown]
# There are no missing values.

# %% [markdown]
# #### **2.4.How many of each risk level?**

# %%
risk_levels = df["RiskLevel"].value_counts()
risk_levels_df = pd.DataFrame(risk_levels)
risk_levels_df = risk_levels.reset_index(level = 0)
risk_levels_df
# Out:
#    RiskLevel  count
# 0   low risk    406
# 1   mid risk    336
# 2  high risk    272

# %%
# Plotting risk level counts and rates
cmap = ["#3a923a","#e1812c","#c03d3e","#3274a1","#857aab","#8d7866"]

plt.subplots(1, 2, figsize = (10, 4))
plt.subplot(121)
ax = sns.barplot(data = risk_levels_df, 
                 x = risk_levels_df["RiskLevel"], 
                 y = risk_levels_df["count"],
                 palette = cmap)
ax.bar_label(ax.containers[0])
plt.title("Risk Level Count");

plt.subplot(122) 
plt.pie(x = risk_levels, 
        explode = [0.1, 0.1, 0.1],
        labels = risk_levels.index,
        colors = cmap,
        autopct = "%.1f%%", 
        shadow = True)
plt.title("Risk Levels Rate");

# %% [markdown]
# There is an unbalanced distribution among risk levels.

# %% [markdown]
# #### **2.5.General description of data (count, mean, std, min, max and quartiles)**

# %%
df.describe().T
# Out:
#               count        mean        std   min    25%    50%    75%    max
# Age          1014.0   29.871795  13.474386  10.0   19.0   26.0   39.0   70.0
# SystolicBP   1014.0  113.198225  18.403913  70.0  100.0  120.0  120.0  160.0
# DiastolicBP  1014.0   76.460552  13.885796  49.0   65.0   80.0   90.0  100.0
# BS           1014.0    8.725986   3.293532   6.0    6.9    7.5    8.0   19.0
# BodyTemp     1014.0   98.665089   1.371384  98.0   98.0   98.0   98.0  103.0
# HeartRate    1014.0   74.301775   8.088702   7.0   70.0   76.0   80.0   90.0

# %% [markdown]
# Actually some values make no sense for pregnancy like age 10 and 70 or heart rate 7. Probably, there are outliers in data set. Let's have a closer look to age and heart rate.

# %%
# Age and heart rate frequency
plt.subplots(1, 2, figsize = (10, 4))
plt.subplot(121)
df.Age.plot.hist(color = "#3a923a")
plt.title("Age Frequency");

plt.subplot(122) 
df.HeartRate.plot.hist(color = "#c03d3e")
plt.title("HeartRate Frequency");

# %% [markdown]
# The heart rate value "7" is definitely an outlier, most likely entered incorrectly. On the other hand most of the observations seem to be in the 20 - 30 age range. Then comes the 10 - 20 age range.

# %%
# A more detailed view to age distribution
px.box(df.Age, orientation = "h", points = "all")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="3bc1bb19-e2dc-4897-be86-0dc3c3e0dbba" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3bc1bb19-e2dc-4897-be86-0dc3c3e0dbba")) {                    Plotly.newPlot(                        "3bc1bb19-e2dc-4897-be86-0dc3c3e0dbba",                        [{"alignmentgroup":"True","boxpoints":"all","hovertemplate":"value=%{x}\u003cbr\u003evariable=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[25,35,29,30,35,23,23,35,32,42,23,19,25,20,48,15,50,25,30,10,40,50,21,18,21,16,19,22,49,28,20,23,22,21,21,12,60,55,45,35,22,23,25,30,23,32,42,23,15,15,25,22,35,19,60,23,32,42,23,15,15,15,12,29,31,29,17,19,20,32,26,29,19,54,44,23,22,55,35,21,16,33,12,28,21,18,21,16,19,23,22,60,13,23,28,50,29,19,19,60,55,25,48,25,23,34,50,25,42,32,50,38,39,30,63,25,30,55,32,30,48,49,25,40,32,35,54,55,29,48,40,32,35,54,40,22,40,55,50,18,32,17,17,25,17,14,15,15,12,37,18,21,17,25,23,12,28,40,55,25,35,21,18,21,16,19,40,32,22,49,28,12,20,23,22,21,35,54,40,21,12,60,55,50,60,55,45,35,22,13,23,17,28,50,25,30,31,23,29,17,32,42,23,19,15,33,48,15,25,22,50,35,19,60,28,50,29,30,31,23,29,17,32,42,23,19,15,29,48,15,50,25,55,20,40,28,32,17,17,25,17,19,15,32,12,37,18,21,17,25,10,12,28,40,55,25,35,21,18,21,16,19,40,32,22,49,28,12,20,23,22,21,35,54,40,21,12,60,55,50,60,55,45,35,22,13,23,17,26,50,19,30,31,23,29,17,32,42,23,19,15,40,48,15,25,22,12,35,19,60,55,35,51,62,25,21,22,55,54,35,43,12,65,60,25,22,66,56,35,43,35,44,23,22,55,35,21,45,70,65,55,45,22,16,12,37,18,21,17,25,33,12,28,40,55,25,35,21,18,21,16,19,40,32,23,22,21,35,54,40,21,12,60,55,50,60,55,45,35,22,13,23,17,28,50,19,30,31,23,29,17,32,42,23,19,15,20,48,15,25,22,12,35,19,60,55,25,22,12,35,19,60,55,50,27,60,55,60,12,17,60,22,36,22,25,35,40,27,36,22,25,35,40,27,27,65,35,29,30,35,23,23,35,32,43,23,19,15,30,48,15,48,25,29,32,35,23,23,34,32,42,23,19,15,20,48,15,50,25,30,31,42,18,32,17,19,15,19,48,15,25,22,50,35,19,60,38,50,39,30,31,23,29,17,32,42,23,19,15,16,48,15,63,25,30,17,55,18,32,17,17,25,17,19,15,60,18,50,19,30,31,23,29,17,32,42,42,19,15,23,48,15,49,25,30,16,16,19,40,32,22,49,28,12,20,23,22,21,35,54,40,21,12,60,55,50,60,55,45,35,22,13,23,17,28,59,29,23,31,23,29,17,32,42,23,19,15,20,48,15,24,16,19,40,32,22,49,28,12,20,23,22,21,35,54,40,21,22,40,55,50,60,40,55,50,41,55,45,35,22,13,23,17,27,50,34,32,31,23,29,17,32,42,23,19,15,20,48,15,24,22,50,35,19,30,28,50,35,29,19,46,28,50,39,25,31,23,29,17,32,42,23,19,15,34,48,15,27,25,36,30,15,40,15,21,15,21,15,15,15,10,15,15,12,15,35,29,30,23,35,42,50,25,40,32,14,37,17,40,40,20,15,24,19,31,23,23,19,15,34,15,15,21,15,12,21,23,32,19,20,48,30,18,17,17,25,17,13,31,29,19,28,50,29,31,29,17,19,20,19,20,48,30,18,17,17,25,17,13,31,29,19,28,50,29,31,29,17,19,20,32,26,29,19,54,44,23,22,55,35,21,16,33,12,28,21,18,21,16,19,23,22,60,13,23,28,50,29,19,19,60,55,25,12,35,19,60,50,27,55,12,60,25,22,30,35,23,43,19,30,32,23,42,19,31,19,25,31,23,29,48,18,18,29,23,15,30,40,60,50,28,31,23,29,22,49,28,12,20,23,22,21,60,50,17,29,19,19,30,28,50,39,29,17,32,42,36,30,15,10,12,12,23,32,19,20,48,30,18,17,17,25,17,13,31,29,19,28,50,29,31,29,17,19,20,32,27,27,32,23,15,15,29,35,32,23,15,20,48,15,30,18,17,15,19,48,15,22,35,19,60,50,17,32,42,23,19,15,16,15,17,17,17,25,17,19,15,60,50,19,31,23,17,32,42,42,19,15,16,16,19,22,49,28,12,20,23,22,21,21,12,60,55,45,35,22,13,23,17,59,23,17,32,42,25,40,32,14,37,17,40,40,32,12,35,54,40,60,55,50,17,28,50,17,33,48,50,30,29,48,50,25,55,40,28,32,17,17,25,17,19,37,17,25,40,32,12,35,54,40,12,60,55,50,13,17,17,40,48,22,55,35,43,32],"x0":" ","xaxis":"x","y":["Age","Age","Age","Age","Age","Age","Age","Age","Age","Age","Age","Age","Age","Age","Age","Age","Age","Age","Age","Age","Age","Age ...

# %% [markdown]
# The age value "70" can be considered an outlier, but "10" to "14" range is controversial. In fact, the discussion here indicates that the data set has real values: https://www.kaggle.com/datasets/csafrit2/maternal-health-risk-data/discussion/297518

# %%
# Other feature distributions by age
columns = df.columns[1:6]
for i in range(len(columns)):
    plt.figure(figsize = (8, 5))
    sns.kdeplot(data = df, 
                x = columns[i], 
                y = "Age",
                color = "#636efa").set(title = f"{columns[i]} by Age");

# %% [markdown]
# #### **2.6.Distribution of features**

# %%
# General distribution
sns.pairplot(df.iloc[:,:], hue = "RiskLevel");

# %%
plt.figure(figsize = (20, 15))
for i, col in enumerate(df.iloc[:, 0:6]):
    plt.subplot(3, 3, i + 1)
    sns.boxplot(data = df.iloc[:, 0:6], x = col, color = "#a9c9a4")
    plt.xlabel(col, fontsize = 15)
    plt.xticks(fontsize = 10)

# %% [markdown]
# General age distribution on data set is in range 20-40. SystolicBP range 100-120, DiastolicBP range 60-90, BS range 7-8, HeartRate 70-80 and BodyTemp is mostly 98.

# %% [markdown]
# #### **2.7.Risk levels by features**

# %%
columns = df.columns[:len(df.columns) - 1]
for i in range(len(columns)):
    plt.figure(figsize = (8, 5))
    sns.catplot(data = df, 
                x = "RiskLevel", 
                y = columns[i], 
                kind = "box", 
                palette = ["#c03d3e","#3a923a","#e1812c"]).set(title = f"Risk Levels by {columns[i]}");

# %% [markdown]
# In general, it can be said that there is a linear relationship between features and risk levels. That means as feature values increase, the risk level also increases. Body temperature is an exception here because it breaks the pattern. Also there appear to be outliers in most features. We should deeply examine and handle them somehow.

# %% [markdown]
# #### **2.8.Encoding categorical features**

# %%
# "low risk": 0, 
# "mid risk": 1, 
# "high risk": 2
risk_map = {"low risk": 0, "mid risk": 1, "high risk": 2}
df["RiskLevel"] = df["RiskLevel"].map(risk_map)
df
# Out:
#       Age  SystolicBP  DiastolicBP    BS  BodyTemp  HeartRate  RiskLevel
# 0      25         130           80  15.0      98.0         86          2
# 1      35         140           90  13.0      98.0         70          2
# 2      29          90           70   8.0     100.0         80          2
# 3      30         140           85   7.0      98.0         70          2
# 4      35         120           60   6.1      98.0         76          0
# ...   ...         ...          ...   ...       ...        ...        ...
# 1009   22         120           60  15.0      98.0         80          2
# 1010   55         120           90  18.0      98.0         60          2
# 1011   35          85           60  19.0      98.0         86          2
# 1012   43         120           90  18.0      98.0         70          2
# 1013   32         120           65   6.0     101.0         76          1
#
# [1014 rows x 7 columns]

# %% [markdown]
# #### **2.9.Correlations**

# %%
df.corr()
# Out:
#                   Age  SystolicBP  DiastolicBP        BS  BodyTemp  HeartRate  \
# Age          1.000000    0.416045     0.398026  0.473284 -0.255323   0.079798
# SystolicBP   0.416045    1.000000     0.787006  0.425172 -0.286616  -0.023108
# DiastolicBP  0.398026    0.787006     1.000000  0.423824 -0.257538  -0.046151
# BS           0.473284    0.425172     0.423824  1.000000 -0.103493   0.142867
# BodyTemp    -0.255323   -0.286616    -0.257538 -0.103493  1.000000   0.098771
# HeartRate    0.079798   -0.023108    -0.046151  0.142867  0.098771   1.000000
# RiskLevel    0.267225    0.396473     0.346649  0.569942  0.163984   0.194312
#
#              RiskLevel
# Age           0.267225
# SystolicBP    0.396473
# DiastolicBP   0.346649
# BS            0.569942
# BodyTemp      0.163984
# HeartRate     0.194312
# RiskLevel     1.000000

# %%
# Correlation matrix
corr_matrix = df.corr()
fig, ax = plt.subplots(figsize = (15, 10))
ax = sns.heatmap(corr_matrix,
                 annot = True,
                 linewidths = 0.5,
                 fmt = ".2f",
                 cmap = "Greens");
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
# Out:
# (7.5, -0.5)

# %% [markdown]
# The correlation matrix tells that DiastolicBP and SystolicBP are highly correlated to each other. On the other hand blood pressure values and blood sugar are correlated to age. Also risk level depends mostly on blood sugar. Then comes blood pressure values and age. Heart rate and body temperature are least effective features on risk level here. Actually it is expected that age to be more decisive on the risk level, but the wide age distribution in the data set seems to reduce this effect.

# %% [markdown]
# #### **2.10.Detecting Outliers**

# %%
# Creating fence list
def createFenceList(df):
    feature_list = []
    q1_list = []
    q3_list = []
    iqr_list = []
    low_list = []
    up_list = []
    for col in df.columns:
        feature_list.append(col)
        q1 = df[col].quantile(0.25)
        q1_list.append(q1)
        q3 = df[col].quantile(0.75)
        q3_list.append(q3)
        iqr = q3 - q1
        iqr_list.append(iqr)

        lower_fence = q1 - (1.5 * iqr)
        low_list.append(lower_fence)
        upper_fence = q3 + (1.5 * iqr)
        up_list.append(upper_fence)
        
        list_of_lists = [q1_list, q3_list, iqr_list, low_list, up_list]
        fence_list = pd.DataFrame(list_of_lists, index = ["q1", "q2", "iqr", "lowerFence", "upperFence"],
                columns = feature_list)       
    return fence_list

# %%
createFenceList(df.iloc[:, 0:6])
# Out:
#              Age  SystolicBP  DiastolicBP    BS  BodyTemp  HeartRate
# q1          19.0       100.0         65.0  6.90      98.0       70.0
# q2          39.0       120.0         90.0  8.00      98.0       80.0
# iqr         20.0        20.0         25.0  1.10       0.0       10.0
# lowerFence -11.0        70.0         27.5  5.25      98.0       55.0
# upperFence  69.0       150.0        127.5  9.65      98.0       95.0

# %%
# How many outliers of each feature?
def detectOutliers(df):
    outliers = pd.DataFrame(columns = ["Feature", "Number of Outliers"])
    features = []
    numbers = []
    for col in df.columns:
        features.append(col)
        #Return values at the given quantile
        q1 = df[col].quantile(0.25)
        q3 = df[col].quantile(0.75)
        iqr = q3 - q1
        lower_fence = q1 - (1.5 * iqr)
        upper_fence = q3 + (1.5 * iqr)
        num_of_out = df.loc[(df[col] < lower_fence) | (df[col] > upper_fence)].shape[0]
        numbers.append(num_of_out)

        lower_fence = df.loc[(df[col] < lower_fence), col]
        upper_fence = df.loc[(df[col] > upper_fence), col] 

    outliers["Feature"] = features
    outliers["Number of Outliers"] = numbers
    
    print("Total number of outliers:", outliers["Number of Outliers"].sum())
    print("Percentage of outliers: % {:.3f}".format(outliers["Number of Outliers"].sum()/df.shape[0]))
    return outliers

# %%
detectOutliers(df.iloc[:, 0:6])
# Out:
# Total number of outliers: 433
# Percentage of outliers: % 0.427
#        Feature  Number of Outliers
# 0          Age                   1
# 1   SystolicBP                  10
# 2  DiastolicBP                   0
# 3           BS                 210
# 4     BodyTemp                 210
# 5    HeartRate                   2

# %% [markdown]
# There are so many outliers in data set. We want to examine them more detailed.

# %%
# Outliers by risk levels depending on age
plt.figure(figsize = (8, 5))
sns.catplot(data = df, 
            x = "Age", 
            y = "RiskLevel",
            kind = "box", 
            palette = ["#3a923a", "#e1812c", "#c03d3e"],
            orient = "h").set(title = "Outliers by risk levels depending on age");

# %%
print("\033[1m" + "Low Risk by Age > 50: ", ((df["Age"] > 50) & (df["RiskLevel"] == 0)).sum())
print("\033[1m" + "Mid Risk by Age > 50: ", ((df["Age"] > 50) & (df["RiskLevel"] == 1)).sum())
print("\033[0m" + "High Risk by Age > 50: ", ((df["Age"] > 50) & (df["RiskLevel"] == 2)).sum())
# Out:
# Low Risk by Age > 50:  33
# Mid Risk by Age > 50:  25
# High Risk by Age > 50:  37

# %%
# Outliers by risk levels depending on blood sugar
plt.figure(figsize = (8, 5))
sns.catplot(data = df, 
            x = "BS", 
            y = "RiskLevel",
            kind = "box", 
            palette = ["#3a923a", "#e1812c", "#c03d3e"],
            orient = "h").set(title = "Outliers by risk levels depending on blood sugar");

# %%
print("\033[1m" + "Low Risk by BS > 10: ", ((df["BS"] > 10) & (df["RiskLevel"] == 0)).sum())
print("\033[1m" + "Mid Risk by BS > 10: ", ((df["BS"] > 10) & (df["RiskLevel"] == 1)).sum())
print("\033[0m" + "High Risk by BS > 10: ", ((df["BS"] > 10) & (df["RiskLevel"] == 2)).sum())
# Out:
# Low Risk by BS > 10:  4
# Mid Risk by BS > 10:  32
# High Risk by BS > 10:  170

# %%
# Outliers by risk levels depending on body temperature
plt.figure(figsize = (8, 5))
sns.catplot(data = df, 
            x = "BodyTemp", 
            y = "RiskLevel",
            kind = "box", 
            palette = ["#3a923a", "#e1812c", "#c03d3e"],
            orient = "h").set(title = "Outliers by risk levels depending on body temperature");

# %%
print("\033[1m" + "Low Risk by BodyTemp > 100: ", ((df["BodyTemp"] > 100) & (df["RiskLevel"] == 0)).sum())
print("\033[0m" + "Mid Risk by BodyTemp > 100: ", ((df["BodyTemp"] > 100) & (df["RiskLevel"] == 1)).sum())
print("\033[0m" + "High Risk by BodyTemp > 100: ", ((df["BodyTemp"] > 100) & (df["RiskLevel"] == 2)).sum())
# Out:
# Low Risk by BodyTemp > 100:  37
# Mid Risk by BodyTemp > 100:  75
# High Risk by BodyTemp > 100:  65

# %% [markdown]
# It is indicated before that there is a linear relationship between features and risk levels. So it is expected that as feature values increase, the risk level also increases. Now we determined outliers by risk levels which is not increased as feature values increase. That means high values and low 'low & mid risk level' counts.
#
# Besides we determined the upper fence of age as 50 because a quick google search (just one of examples: https://en.wikipedia.org/wiki/Pregnancy_over_age_50) shows that pregnancies over age 50 are very unlikely and considered exceptional. So, we can consider them as outliers. Likewise, blood sugar over 10-11 considered as diabetes and body temperature over 100.4 considered as high fever. It is expected that these ilnesses increase risk levels. But we can't observe their effects on risk levels above. So, we consider them as outliers, too. We determined heart rate "7" as outlier before. Now we can get rid of the outliers with peace of mind. :)

# %% [markdown]
# # **3.Data preprocessing**

# %% [markdown]
# #### **3.1.Removing Outliers**

# %%
df = df[~((df["BodyTemp"] > 100) & (df["RiskLevel"] == 0))]
df = df[~((df["BS"] > 10) & (df["RiskLevel"] == 0) | (df["BS"] > 10) & (df["RiskLevel"] == 1))]
df = df[~((df["Age"] > 50) & (df["RiskLevel"] == 0) | (df["Age"] > 50) & (df["RiskLevel"] == 1))]
df = df[~(df["HeartRate"] < 55)]
df
# Out:
#       Age  SystolicBP  DiastolicBP    BS  BodyTemp  HeartRate  RiskLevel
# 0      25         130           80  15.0      98.0         86          2
# 1      35         140           90  13.0      98.0         70          2
# 2      29          90           70   8.0     100.0         80          2
# 3      30         140           85   7.0      98.0         70          2
# 4      35         120           60   6.1      98.0         76          0
# ...   ...         ...          ...   ...       ...        ...        ...
# 1009   22         120           60  15.0      98.0         80          2
# 1010   55         120           90  18.0      98.0         60          2
# 1011   35          85           60  19.0      98.0         86          2
# 1012   43         120           90  18.0      98.0         70          2
# 1013   32         120           65   6.0     101.0         76          1
#
# [895 rows x 7 columns]

# %% [markdown]
# Now there are 895 observations without outliers. Let's have look risk level distributions one more time.

# %%
# Risk level counts
risk_levels = df["RiskLevel"].value_counts()
risk_levels_df = pd.DataFrame(risk_levels)
risk_levels_df = risk_levels.reset_index(level = 0)
risk_levels_df
# Out:
#    RiskLevel  count
# 0          0    333
# 1          1    290
# 2          2    272

# %%
# Plotting risk level counts and rates
cmap = ["#3a923a","#e1812c","#c03d3e","#3274a1","#857aab","#8d7866"]

plt.subplots(1, 2, figsize = (10, 4))
plt.subplot(121)
ax = sns.barplot(data = risk_levels_df, 
                 x = risk_levels_df["RiskLevel"], 
                 y = risk_levels_df["count"],
                 palette = cmap)
ax.bar_label(ax.containers[0])
ax.set_xticklabels(["low risk", "mid risk", "high risk"])
plt.title("Risk Level Count");

plt.subplot(122) 
plt.pie(x = risk_levels, 
        explode = [0.1, 0.1, 0.1],
        labels = ["low risk", "mid risk", "high risk"],
        colors = cmap,
        autopct = "%.1f%%", 
        shadow = True)
plt.title("Risk Levels Rate");

# %% [markdown]
# Now we have data set that have more balanced distribution.

# %% [markdown]
# #### **3.2.Splitting**

# %%
# Split data into features and target
X = df.drop(["RiskLevel"], axis = 1)
y = df["RiskLevel"]

# %%
X
# Out:
#       Age  SystolicBP  DiastolicBP    BS  BodyTemp  HeartRate
# 0      25         130           80  15.0      98.0         86
# 1      35         140           90  13.0      98.0         70
# 2      29          90           70   8.0     100.0         80
# 3      30         140           85   7.0      98.0         70
# 4      35         120           60   6.1      98.0         76
# ...   ...         ...          ...   ...       ...        ...
# 1009   22         120           60  15.0      98.0         80
# 1010   55         120           90  18.0      98.0         60
# 1011   35          85           60  19.0      98.0         86
# 1012   43         120           90  18.0      98.0         70
# 1013   32         120           65   6.0     101.0         76
#
# [895 rows x 6 columns]

# %%
y
# Out:
# 0       2
# 1       2
# 2       2
# 3       2
# 4       0
#        ..
# 1009    2
# 1010    2
# 1011    2
# 1012    2
# 1013    1
# Name: RiskLevel, Length: 895, dtype: int64

# %%
# Split into train and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, stratify = y, random_state = seed)

# %% [markdown]
# #### **3.3.Standardization**

# %%
scaler = preprocessing.StandardScaler()
scaler.fit(X_train)
X_trainStandart = scaler.transform(X_train)
X_testStandart = scaler.transform(X_test)

# %%
X_trainStandart, len(X_trainStandart)
# Out:
# (array([[-0.30136064,  0.32294202,  0.91464163, -0.59705876,  1.94099147,
#           0.72194873],
#         [-0.4741978 ,  0.32294202,  0.91464163, -0.26472668, -0.45557788,
#          -1.91788717],
#         [-0.64703496,  0.32294202,  0.20689669, -0.53663474, -0.45557788,
#           0.19398155],
#         ...,
#         [ 0.30356942,  1.41246886,  1.62238658, -0.23451467, -0.45557788,
#           0.45796514],
#         [-0.73345354, -0.76658482,  0.91464163, -0.50642273, -0.45557788,
#           1.77788309],
#         [-0.81987212,  0.32294202,  0.20689669, -0.50642273, -0.45557788,
#          -0.59796922]]),
#  626)

# %%
X_testStandart, len(X_testStandart)
# Out:
# (array([[-1.3383836 , -1.31134824, -0.85472073,  0.09781741,  1.94099147,
#           0.72194873],
#         [-0.73345354,  0.32294202, -0.14697579, -0.3553627 , -0.45557788,
#          -0.59796922],
#         [ 0.73566232,  0.32294202,  0.91464163,  0.70205755, -0.45557788,
#           1.77788309],
#         ...,
#         [-0.30136064,  0.32294202,  0.20689669, -0.50642273, -0.45557788,
#          -1.1259364 ],
#         [-1.42480218, -1.31134824, -1.20859321,  0.70205755,  2.73984791,
#          -1.91788717],
#         [-0.4741978 ,  0.32294202,  0.91464163, -0.29493869, -0.45557788,
#          -1.91788717]]),
#  269)

# %% [markdown]
# # **4.Modelling**

# %%
# Classifier comparison with default parameters
scoresCV = []
classifiers = [KNeighborsClassifier(),
               LogisticRegression(random_state = seed),
               RandomForestClassifier(random_state = seed), 
               GradientBoostingClassifier(random_state = seed),
               DecisionTreeClassifier(random_state = seed),
               SVC(random_state = seed),
               XGBClassifier(random_state = seed)
              ]
for classifier in classifiers:
    pipe = make_pipeline(preprocessing.StandardScaler(), classifier)
    scoreCV = cross_val_score(pipe, 
                              X_train, 
                              y_train, 
                              scoring = "accuracy", 
                              cv = StratifiedKFold(n_splits = 5, 
                                                   shuffle = True,
                                                   random_state = seed))
    scoresCV.append([classifier, np.mean(scoreCV)])

# %%
# Best classifiers according to validation accuracy descending
c_val = pd.DataFrame(scoresCV, columns=["Classifier", "Validation Accuracy"])
c_val_sort = c_val.sort_values(by = "Validation Accuracy", ignore_index = True)
c_val_sort
# Out:
#                                           Classifier  Validation Accuracy
# 0                LogisticRegression(random_state=20)             0.691708
# 1                             KNeighborsClassifier()             0.720356
# 2                               SVC(random_state=20)             0.746019
# 3        GradientBoostingClassifier(random_state=20)             0.816254
# 4            RandomForestClassifier(random_state=20)             0.830654
# 5            DecisionTreeClassifier(random_state=20)             0.832267
# 6  XGBClassifier(base_score=None, booster=None, c...             0.840254

# %% [markdown]
# #### **4.1.Logistic Regression Model**

# %% [markdown]
# ##### **4.4.1.Parameter Tuning**

# %%
# Creating pipeline
pipe = Pipeline([("scaler", preprocessing.StandardScaler()),
                 ("Classifier", LogisticRegression(max_iter = 1000, random_state = seed))])
# Searching parameters
params = [{"Classifier__solver": ["liblinear"], 
           "Classifier__penalty": ["l1", "l2"],
           "Classifier__C": [0.001, 0.01, 0.1, 1, 10, 100, 1000, 10000]}]
# Creating grid
lr_clf_grid = GridSearchCV(estimator = pipe,
                           param_grid = params,
                           cv = StratifiedKFold(n_splits = 10, 
                                                shuffle = True,
                                                random_state = seed),
                           refit = True,
                           verbose = 2,
                           scoring = "accuracy")
# Fit the model
lr_model = lr_clf_grid.fit(X_trainStandart, y_train)

# Get best parameters
print("Best parameters for Logistic Regression model: ", lr_model.best_params_)
# Out:
# Fitting 10 folds for each of 16 candidates, totalling 160 fits
# [CV] END Classifier__C=0.001, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=0.001, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=0.001, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=0.001, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=0.001, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=0.001, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=0.001, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=0.001, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=0.001, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=0.001, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=0.001, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=0.001, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=0.001, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=0.001, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=0.001, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=0.001, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=0.001, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=0.001, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=0.001, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=0.001, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=0.01, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=0.01, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=0.01, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=0.01, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=0.01, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=0.01, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=0.01, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=0.01, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=0.01, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=0.01, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=0.01, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=0.01, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=0.01, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=0.01, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=0.01, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=0.01, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=0.01, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=0.01, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=0.01, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=0.01, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=0.1, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=0.1, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=0.1, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=0.1, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=0.1, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=0.1, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=0.1, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=0.1, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=0.1, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=0.1, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=0.1, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=0.1, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=0.1, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=0.1, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=0.1, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=0.1, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=0.1, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=0.1, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=0.1, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=0.1, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=1, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=1, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=1, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=1, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=1, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=1, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=1, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=1, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=1, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=1, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=1, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=1, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=1, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=1, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=1, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=1, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=1, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=1, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=1, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=1, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=10, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=10, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=10, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=10, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=10, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=10, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=10, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=10, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=10, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=10, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=10, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=10, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=10, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=10, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=10, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=10, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=10, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=10, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=10, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=10, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=100, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=100, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=100, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=100, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=100, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=100, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=100, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=100, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=100, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=100, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=100, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=100, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=100, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=100, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=100, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=100, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=100, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=100, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=100, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=100, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=1000, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=1000, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=1000, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=1000, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=1000, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=1000, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=1000, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=1000, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=1000, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=1000, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=1000, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=1000, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=1000, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=1000, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=1000, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=1000, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=1000, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=1000, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=1000, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=1000, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=10000, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=10000, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=10000, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=10000, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=10000, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=10000, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=10000, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=10000, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=10000, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=10000, Classifier__penalty=l1, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=10000, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=10000, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=10000, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=10000, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=10000, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=10000, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=10000, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=10000, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=10000, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# [CV] END Classifier__C=10000, Classifier__penalty=l2, Classifier__solver=liblinear; total time=   0.0s
# Best parameters for Logistic Regression model:  {'Classifier__C': 0.1, 'Classifier__penalty': 'l1', 'Classifier__solver': 'liblinear'}

# %%
# Best parameters
lr_best = pd.DataFrame.from_dict(lr_model.best_params_, orient = "index").rename(columns = {0: "Best"})
lr_best
# Out:
#                           Best
# Classifier__C              0.1
# Classifier__penalty         l1
# Classifier__solver   liblinear

# %% [markdown]
# ##### **4.1.2.Building model with best parameters**

# %%
lr_clf = LogisticRegression(C = float(lr_best.iloc[0,0]),
                            penalty = lr_best.iloc[1,0],
                            solver = lr_best.iloc[2,0],
                            max_iter = 1000, 
                            random_state = seed)
# Fitting the model
lr_clf.fit(X_trainStandart, y_train)
# Out:
# LogisticRegression(C=0.1, max_iter=1000, penalty='l1', random_state=20,
#                    solver='liblinear')

# %% [markdown]
# ##### **4.1.3.Predictions and model accuracy**

# %%
lr_pred = lr_clf.predict(X_testStandart)
lr_acc = accuracy_score(y_test, lr_pred)
print("Logistic Regression Model Accuracy:", lr_acc)
lr_acc_tr = lr_clf.score(X_trainStandart, y_train)
print("Logistic Regression Training Accuracy:", lr_acc_tr)
# Out:
# Logistic Regression Model Accuracy: 0.7286245353159851
# Logistic Regression Training Accuracy: 0.7204472843450479

# %% [markdown]
# ##### **4.1.4.Other test parameters**

# %%
# Classification Report
print("Logistic Regression Classification Report\n\n", classification_report(y_test, lr_pred))
# Out:
# Logistic Regression Classification Report
#
#                precision    recall  f1-score   support
#
#            0       0.67      0.95      0.79       100
#            1       0.64      0.43      0.51        87
#            2       0.91      0.78      0.84        82
#
#     accuracy                           0.73       269
#    macro avg       0.74      0.72      0.71       269
# weighted avg       0.74      0.73      0.71       269

# %%
# For comparison list records
lr_recall = recall_score(y_test, lr_pred, average = None)
lr_prec = precision_score(y_test, lr_pred, average = None)
lr_f1 = f1_score(y_test, lr_pred, average = None)

# %%
#Confusion matrix
lr_cm = confusion_matrix(y_test, lr_pred, labels = lr_clf.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix = lr_cm,
                              display_labels = lr_clf.classes_)
print("Logistic Regression Confusion Matrix")
disp.plot()
plt.show()
# Out:
# Logistic Regression Confusion Matrix

# %%
# Prediction rates
def calculatePredictionRates(model_name, acc, cm):
    print(f"""
    The success rate of the {model_name} model on the test set: {(acc*100):.0f}%
    Low risk correct prediction rate: {((cm[0][0]/sum(cm[0]))*100):.0f}%
    Mid risk correct prediction rate: {((cm[1][1]/sum(cm[1]))*100):.0f}%
    High risk correct prediction rate: {((cm[2][2]/sum(cm[1]))*100):.0f}%""")

# %%
calculatePredictionRates("Logistic Regression", lr_acc, lr_cm)
# Out:
#     The success rate of the Logistic Regression model on the test set: 73%
#     Low risk correct prediction rate: 95%
#     Mid risk correct prediction rate: 43%
#     High risk correct prediction rate: 74%

# %%
# Train/Test Performance Metrics
def calculatePerformance(classifier, X_train, y_train, X_test, y_test):
    train_pred = classifier.predict(X_train)
    test_pred = classifier.predict(X_test)
    scores = {
        "Train Accuracy": accuracy_score(y_train, train_pred), 
        "Test Accuracy": accuracy_score(y_test, test_pred),
        "Train Recall": recall_score(y_train, train_pred, average = None),
        "Test Recall": recall_score(y_test, test_pred, average = None),
        "Train Precision": precision_score(y_train, train_pred, average = None), 
        "Test Precision": precision_score(y_test, test_pred, average = None), 
        "Train F1": f1_score(y_train, train_pred, average = None),
        "Test F1": f1_score(y_test, test_pred, average = None) 
    }
    print("Model Performance Metrics Comparison")
    return scores

# %%
lr_pm = pd.DataFrame(calculatePerformance(lr_clf, X_trainStandart, y_train, X_testStandart, y_test))*100
lr_pm
# Out:
# Model Performance Metrics Comparison
#    Train Accuracy  Test Accuracy  Train Recall  Test Recall  Train Precision  \
# 0       72.044728      72.862454     94.849785    95.000000        66.167665
# 1       72.044728      72.862454     42.857143    42.528736        63.970588
# 2       72.044728      72.862454     75.263158    78.048780        91.666667
#
#    Test Precision   Train F1    Test F1
# 0       67.375887  77.954145  78.838174
# 1       63.793103  51.327434  51.034483
# 2       91.428571  82.658960  84.210526

# %%
# Creating comparison lists
metrics = ["Accuracy", "Precision", "Recall", "F1 Score"]
model_names = []
clf_list = []
pred_list = []
acc_list = []
cm_list = []
f1_list = []
performs = []
prec_list = []
recall_list = []
tr_acc_list = []
# Updating comparison lists
def updateLists(model_name, clf, pred, acc, cm, f1, pm, prec, recall, acc_tr):
    model_names.append(model_name) 
    clf_list.append(clf)
    pred_list.append(pred)
    acc_list.append(acc)
    cm_list.append(cm)
    f1_list.append(f1)
    performs.append(pm)
    prec_list.append(prec)
    recall_list.append(recall)
    tr_acc_list.append(acc_tr)

# %%
updateLists("LogisticRegression", lr_clf, lr_pred, lr_acc, lr_cm, lr_f1, lr_pm, lr_prec, lr_recall, lr_acc_tr)

# %% [markdown]
# #### **4.2.SVC Model**

# %% [markdown]
# ##### **4.2.1.Parameter Tuning**

# %%
# Creating model pipeline
pipe = Pipeline([("scaler", preprocessing.StandardScaler()),
                 ("Classifier", SVC(random_state = seed))])
# Searching parameters
params = [{"Classifier__kernel": ["rbf", "linear"], 
           "Classifier__gamma": [1, 0.1, 0.01, 0.001],
           "Classifier__C": [1, 10, 100, 1000]}
         ]
# Creating grid
svc_clf_grid = RandomizedSearchCV(estimator = pipe, 
                                  param_distributions = params,
                                  cv = StratifiedKFold(n_splits = 10, 
                                                       shuffle = True,
                                                       random_state = seed),
                                  n_iter = 10,
                                  verbose = 2, 
                                  scoring = "accuracy",
                                  n_jobs = -1)
# Fit the model
svc_model = svc_clf_grid.fit(X_trainStandart, y_train)

# Get best parameters
print("Best parameters for SVC model: ", svc_model.best_params_)
# Out:
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Best parameters for SVC model:  {'Classifier__kernel': 'rbf', 'Classifier__gamma': 1, 'Classifier__C': 100}

# %%
# Best parameters
svc_best = pd.DataFrame.from_dict(svc_model.best_params_, orient = "index").rename(columns = {0: "Best"})
svc_best
# Out:
#                    Best
# Classifier__kernel  rbf
# Classifier__gamma     1
# Classifier__C       100

# %% [markdown]
# ##### **4.2.2.Building model with best parameters**

# %%
svc_clf = SVC(kernel = svc_best.iloc[0,0], 
              gamma = float(svc_best.iloc[1,0]),
              C = float(svc_best.iloc[2,0]),
              random_state = seed,
              probability = True)
# Fit the model
svc_clf.fit(X_trainStandart, y_train)
# Out:
# SVC(C=100.0, gamma=1.0, probability=True, random_state=20)

# %% [markdown]
# ##### **4.2.3.Predictions and model accuracy**

# %%
svc_model = svc_clf.fit(X_trainStandart, y_train)
svc_pred = svc_clf.predict(X_testStandart)
svc_acc = accuracy_score(y_test, svc_pred)
print("SVC Model Accuracy:", svc_acc)
svc_acc_tr = svc_clf.score(X_trainStandart, y_train)
print("SVC Training Accuracy:", svc_acc_tr)
# Out:
# SVC Model Accuracy: 0.7992565055762082
# SVC Training Accuracy: 0.9089456869009584

# %% [markdown]
# ##### **4.2.4.Other test parameters**

# %%
# Classification Report
print("SVC Classification Report\n\n", classification_report(y_test, svc_pred))
# Out:
# SVC Classification Report
#
#                precision    recall  f1-score   support
#
#            0       0.78      0.76      0.77       100
#            1       0.70      0.75      0.72        87
#            2       0.94      0.90      0.92        82
#
#     accuracy                           0.80       269
#    macro avg       0.81      0.80      0.80       269
# weighted avg       0.80      0.80      0.80       269

# %%
#  For comparison list records
svc_recall = recall_score(y_test, svc_pred, average = None)
svc_prec = precision_score(y_test, svc_pred, average = None)
svc_f1 = f1_score(y_test, svc_pred, average = None)

# %%
# Confusion matrix
svc_cm = confusion_matrix(y_test, svc_pred, labels = svc_clf.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix = svc_cm,
                              display_labels = svc_clf.classes_)
print("SVC Confusion Matrix")
disp.plot()
plt.show();
# Out:
# SVC Confusion Matrix

# %%
# Prediction rates
calculatePredictionRates("SVC", svc_acc, svc_cm)
# Out:
#     The success rate of the SVC model on the test set: 80%
#     Low risk correct prediction rate: 76%
#     Mid risk correct prediction rate: 75%
#     High risk correct prediction rate: 85%

# %%
# Train/Test Performance Metrics
svc_pm = pd.DataFrame(calculatePerformance(svc_clf, X_trainStandart, y_train, X_testStandart, y_test))*100
svc_pm
# Out:
# Model Performance Metrics Comparison
#    Train Accuracy  Test Accuracy  Train Recall  Test Recall  Train Precision  \
# 0       90.894569      79.925651     90.987124    76.000000        87.603306
# 1       90.894569      79.925651     85.714286    74.712644        87.000000
# 2       90.894569      79.925651     96.315789    90.243902        99.456522
#
#    Test Precision   Train F1    Test F1
# 0       78.350515  89.263158  77.157360
# 1       69.892473  86.352357  72.222222
# 2       93.670886  97.860963  91.925466

# %%
# Updating comparison lists
updateLists("SVC", svc_clf, svc_pred, svc_acc, svc_cm, svc_f1, svc_pm, svc_prec, svc_recall, svc_acc_tr)

# %% [markdown]
# #### **4.3.Random Forest Model**

# %% [markdown]
# ##### **4.3.1.Parameter Tuning**

# %%
# Creating model
clf = RandomForestClassifier(random_state = seed)
# Searching parameters
params = {"n_estimators": [100, 200, 300, 400, 500],
          "max_features": np.arange(1,7),
          "max_depth": [3]
         }
# Creating grid
rf_clf_grid = RandomizedSearchCV(estimator = clf, 
                                 param_distributions = params,
                                 cv = StratifiedKFold(n_splits = 10, 
                                                      shuffle = True,
                                                      random_state = seed),
                                 n_iter = 10,
                                 verbose = 2, 
                                 scoring = "accuracy",
                                 n_jobs = -1)
# Fit the model
rf_model = rf_clf_grid.fit(X_train, y_train)

# Get best parameters
print("Best parameters for Random Forest model: ", rf_model.best_params_)
# Out:
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Best parameters for Random Forest model:  {'n_estimators': 100, 'max_features': 2, 'max_depth': 3}

# %%
# Best paramaeters
rf_best = pd.DataFrame.from_dict(rf_model.best_params_, orient = "index").rename(columns = {0: "Best"})
rf_best
# Out:
#               Best
# n_estimators   100
# max_features     2
# max_depth        3

# %% [markdown]
# ##### **4.3.2.Building model with best parameters**

# %%
rf_clf = RandomForestClassifier(n_estimators = int(rf_best.iloc[0,0]),
                                max_features = int(rf_best.iloc[1,0]),
                                max_depth = int(rf_best.iloc[2,0]),
                                random_state = seed)
# Fit the model
rf_clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=3, max_features=2, random_state=20)

# %% [markdown]
# ##### **4.3.3.Predictions and model accuracy**

# %%
rf_pred = rf_clf.predict(X_test)
rf_acc = accuracy_score(y_test, rf_pred)
print("Random Forest Model Accuracy:", rf_acc)
rf_acc_tr = rf_clf.score(X_train, y_train)
print("Random Forest Training Accuracy:", rf_acc_tr)
# Out:
# Random Forest Model Accuracy: 0.758364312267658
# Random Forest Training Accuracy: 0.768370607028754

# %% [markdown]
# ##### **4.3.4.Other test parameters**

# %%
# Classification Report
print("Random Forest Classification Report\n\n", classification_report(y_test, rf_pred))
# Out:
# Random Forest Classification Report
#
#                precision    recall  f1-score   support
#
#            0       0.66      0.97      0.79       100
#            1       0.78      0.41      0.54        87
#            2       0.93      0.87      0.90        82
#
#     accuracy                           0.76       269
#    macro avg       0.79      0.75      0.74       269
# weighted avg       0.78      0.76      0.74       269

# %%
# For comparison list records
rf_recall = recall_score(y_test, rf_pred, average = None)
rf_prec = precision_score(y_test, rf_pred, average = None)
rf_f1 = f1_score(y_test, rf_pred, average = None)

# %%
# Confusion matrix
rf_cm = confusion_matrix(y_test, rf_pred, labels = rf_clf.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix = rf_cm,
                              display_labels = rf_clf.classes_)
print("Random Forest Confusion Matrix")
disp.plot()
plt.show()
# Out:
# Random Forest Confusion Matrix

# %%
# Prediction rates
calculatePredictionRates("Random Forest", rf_acc, rf_cm)
# Out:
#     The success rate of the Random Forest model on the test set: 76%
#     Low risk correct prediction rate: 97%
#     Mid risk correct prediction rate: 41%
#     High risk correct prediction rate: 82%

# %%
# Train/Test Performance Metrics
rf_pm = pd.DataFrame(calculatePerformance(rf_clf, X_train, y_train, X_test, y_test))*100
rf_pm
# Out:
# Model Performance Metrics Comparison
#    Train Accuracy  Test Accuracy  Train Recall  Test Recall  Train Precision  \
# 0       76.837061      75.836431     99.570815    97.000000        65.722380
# 1       76.837061      75.836431     42.364532    41.379310        80.373832
# 2       76.837061      75.836431     85.789474    86.585366        98.192771
#
#    Test Precision   Train F1    Test F1
# 0       65.986395  79.180887  78.542510
# 1       78.260870  55.483871  54.135338
# 2       93.421053  91.573034  89.873418

# %%
# Updating comparison lists
updateLists("RandomForest", rf_clf, rf_pred, rf_acc, rf_cm, rf_f1, rf_pm, rf_prec, rf_recall, rf_acc_tr)

# %% [markdown]
# ##### **4.3.5.Feature Importances**

# %%
# Ploting the impurity-based feature importances
feats = {} # a dictionary to hold feature_name: feature_importance
importances = rf_clf.feature_importances_
rf_clf.feature_importances_
# Out:
# array([0.07817516, 0.23347902, 0.1178215 , 0.43388765, 0.11045273,
#        0.02618394])

# %%
for feature, importance in zip(X.columns, rf_clf.feature_importances_):
    feats[feature] = importance #add the name/value pair 
importances = pd.DataFrame.from_dict(feats, orient = "index").rename(columns = {0: "Gini-importance"})
importances = importances.sort_values(by = "Gini-importance")
importances.plot.barh();

# %% [markdown]
# #### **4.4.Decision Tree Model**

# %% [markdown]
# ##### **4.4.1.Parameter Tuning**

# %%
# Creating model
clf = DecisionTreeClassifier(random_state = seed)
# For ccp_alpha values
path = clf.cost_complexity_pruning_path(X_train, y_train)
alphas = path["ccp_alphas"]
# Searching parameters
params = {"ccp_alpha": alphas,
          "max_features": np.arange(1,7),
          "max_depth": [3]}          
# Creating grid
dt_clf_grid = RandomizedSearchCV(estimator = clf, 
                                 param_distributions = params,
                                 cv = StratifiedKFold(n_splits = 10, 
                                                      shuffle = True,
                                                      random_state = seed),
                                 verbose = 2, 
                                 scoring = "accuracy",
                                 n_jobs = -1)
# Fit the model
dt_model = dt_clf_grid.fit(X_train, y_train)

# Get best parameters
print("Best parameters for Decision Tree model:", dt_model.best_params_)
# Out:
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Best parameters for Decision Tree model: {'max_features': 6, 'max_depth': 3, 'ccp_alpha': 0.001277955271565496}

# %%
# Best parameters
dt_best = pd.DataFrame.from_dict(dt_model.best_params_, orient = "index").rename(columns = {0: "Best"})
dt_best
# Out:
#                   Best
# max_features  6.000000
# max_depth     3.000000
# ccp_alpha     0.001278

# %% [markdown]
# ##### **4.4.2.Building model with best parameters**

# %%
dt_clf = DecisionTreeClassifier(max_features = int(dt_best.iloc[0,0]),
                                max_depth = int(dt_best.iloc[1,0]),
                                ccp_alpha = dt_best.iloc[2,0],
                                random_state = seed)
# Fit the model
dt_clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.001277955271565496, max_depth=3,
#                        max_features=6, random_state=20)

# %% [markdown]
# ##### **4.4.3.Predictions and model accuracy**

# %%
dt_pred = dt_clf.predict(X_test)
dt_acc = accuracy_score(y_test, dt_pred)
print("Decision Tree Model Accuracy:", dt_acc)
dt_acc_tr = dt_clf.score(X_train, y_train)
print("Decision Tree Training Accuracy:", dt_acc_tr)
# Out:
# Decision Tree Model Accuracy: 0.7100371747211895
# Decision Tree Training Accuracy: 0.7268370607028753

# %% [markdown]
# ##### **4.4.4.Other test parameters**

# %%
# Classification Report
print("Decision Tree Classification Report\n\n", classification_report(y_test, dt_pred))
# Out:
# Decision Tree Classification Report
#
#                precision    recall  f1-score   support
#
#            0       0.63      0.96      0.76       100
#            1       0.66      0.33      0.44        87
#            2       0.90      0.80      0.85        82
#
#     accuracy                           0.71       269
#    macro avg       0.73      0.70      0.69       269
# weighted avg       0.72      0.71      0.69       269

# %%
# For comparison list records
dt_recall = recall_score(y_test, dt_pred, average = None)
dt_prec = precision_score(y_test, dt_pred, average = None)
dt_f1 = f1_score(y_test, dt_pred, average = None)

# %%
# Confusion matrix
dt_cm = confusion_matrix(y_test, dt_pred, labels = dt_clf.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix = dt_cm,
                              display_labels = dt_clf.classes_)
print("Decision Tree Confusion Matrix")
disp.plot()
plt.show()
# Out:
# Decision Tree Confusion Matrix

# %%
# Prediction rates
calculatePredictionRates("Decision Tree", dt_acc, dt_cm)
# Out:
#     The success rate of the Decision Tree model on the test set: 71%
#     Low risk correct prediction rate: 96%
#     Mid risk correct prediction rate: 33%
#     High risk correct prediction rate: 76%

# %%
# Train/Test Performance Metrics
dt_pm = pd.DataFrame(calculatePerformance(dt_clf, X_train, y_train, X_test, y_test))*100
dt_pm
# Out:
# Model Performance Metrics Comparison
#    Train Accuracy  Test Accuracy  Train Recall  Test Recall  Train Precision  \
# 0       72.683706      71.003717     99.141631    96.000000        61.600000
# 1       72.683706      71.003717     31.527094    33.333333        72.727273
# 2       72.683706      71.003717     84.210526    80.487805        98.159509
#
#    Test Precision   Train F1    Test F1
# 0       63.157895  75.986842  76.190476
# 1       65.909091  43.986254  44.274809
# 2       90.410959  90.651558  85.161290

# %%
# Updating comparison lists
updateLists("DecisionTree", dt_clf, dt_pred, dt_acc, dt_cm, dt_f1, dt_pm, dt_prec, dt_recall, dt_acc_tr)

# %% [markdown]
# ##### **4.4.5.Feature importances**

# %%
# Ploting the impurity-based feature importances
feats = {} # a dictionary to hold feature_name: feature_importance
importances = dt_clf.feature_importances_
dt_clf.feature_importances_
# Out:
# array([0.        , 0.18322501, 0.        , 0.6539685 , 0.16280648,
#        0.        ])

# %%
for feature, importance in zip(X.columns, dt_clf.feature_importances_):
    feats[feature] = importance #add the name/value pair 
importances = pd.DataFrame.from_dict(feats, orient = "index").rename(columns = {0: "Gini-importance"})
importances = importances.sort_values(by = "Gini-importance")
importances.plot.barh();

# %% [markdown]
# #### **4.5.XGB Classifier**

# %% [markdown]
# ##### **4.5.1.Parameter Tuning**

# %%
# Creating model
clf = XGBClassifier(random_state = seed)
# Searching parameters
params = {"n_estimators": [50, 100, 500, 1000],
          "learning_rate": [1, 0.1, 0.01, 0.001],
          "gamma": [1, 0.1, 0.01, 0.001]
         }
# Creating grid
xg_clf_grid = RandomizedSearchCV(estimator = clf, 
                                 param_distributions = params,
                                 cv = StratifiedKFold(n_splits = 10, 
                                                      shuffle = True,
                                                      random_state = seed),
                                 n_iter = 10,
                                 verbose = 2, 
                                 scoring = "accuracy",
                                 n_jobs = -1)
# Fit the model
xg_model = xg_clf_grid.fit(X_train, y_train)

# Get best parameters
print("Best parameters for XGB model: ", xg_model.best_params_)
# Out:
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# [CV] END Classifier__C=10, Classifier__gamma=0.1, Classifier__kernel=linear; total time=   0.0s
# [CV] END Classifier__C=10, Classifier__gamma=0.1, Classifier__kernel=linear; total time=   0.0s
# [CV] END Classifier__C=10, Classifier__gamma=0.1, Classifier__kernel=linear; total time=   0.0s
# [CV] END Classifier__C=1, Classifier__gamma=0.001, Classifier__kernel=linear; total time=   0.0s
# [CV] END Classifier__C=1, Classifier__gamma=0.001, Classifier__kernel=linear; total time=   0.0s
# [CV] END Classifier__C=1, Classifier__gamma=0.001, Classifier__kernel=linear; total time=   0.0s
# [CV] END Classifier__C=1, Classifier__gamma=1, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=1, Classifier__gamma=1, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=100, Classifier__gamma=0.001, Classifier__kernel=linear; total time=   0.2s
# [CV] END Classifier__C=100, Classifier__gamma=0.001, Classifier__kernel=linear; total time=   0.2s
# [CV] END Classifier__C=10, Classifier__gamma=1, Classifier__kernel=linear; total time=   0.0s
# [CV] END Classifier__C=10, Classifier__gamma=1, Classifier__kernel=linear; total time=   0.0s
# [CV] END Classifier__C=100, Classifier__gamma=1, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=100, Classifier__gamma=1, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=100, Classifier__gamma=1, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=100, Classifier__gamma=1, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=100, Classifier__gamma=1, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=100, Classifier__gamma=1, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=100, Classifier__gamma=1, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=100, Classifier__gamma=1, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=1000, Classifier__gamma=0.01, Classifier__kernel=rbf; total time=   0.1s
# [CV] END Classifier__C=1000, Classifier__gamma=0.01, Classifier__kernel=rbf; total time=   0.1s
# [CV] END Classifier__C=1000, Classifier__gamma=0.01, Classifier__kernel=rbf; total time=   0.1s
# [CV] END Classifier__C=1000, Classifier__gamma=0.01, Classifier__kernel=rbf; total time=   0.1s
# [CV] END Classifier__C=10, Classifier__gamma=0.01, Classifier__kernel=linear; total time=   0.0s
# [CV] END Classifier__C=10, Classifier__gamma=0.01, Classifier__kernel=linear; total time=   0.0s
# [CV] END Classifier__C=10, Classifier__gamma=0.01, Classifier__kernel=linear; total time=   0.0s
# [CV] END Classifier__C=10, Classifier__gamma=0.01, Classifier__kernel=linear; total time=   0.0s
# [CV] END ......max_depth=3, max_features=5, n_estimators=200; total time=   0.6s
# [CV] END ......max_depth=3, max_features=5, n_estimators=200; total time=   0.6s
# [CV] END ......max_depth=3, max_features=3, n_estimators=500; total time=   1.4s
# [CV] END ......max_depth=3, max_features=3, n_estimators=500; total time=   1.4s
# [CV] END ......max_depth=3, max_features=3, n_estimators=500; total time=   1.3s
# [CV] END ......max_depth=3, max_features=4, n_estimators=200; total time=   0.6s
# [CV] END ......max_depth=3, max_features=4, n_estimators=200; total time=   0.6s
# [CV] END ......max_depth=3, max_features=4, n_estimators=500; total time=   1.5s
# [CV] END ......max_depth=3, max_features=4, n_estimators=500; total time=   1.4s
# [CV] END ......max_depth=3, max_features=5, n_estimators=300; total time=   0.9s
# [CV] END ......max_depth=3, max_features=5, n_estimators=300; total time=   0.9s
# [CV] END ......max_depth=3, max_features=5, n_estimators=300; total time=   1.2s
# [CV] END ......max_depth=3, max_features=2, n_estimators=100; total time=   0.3s
# [CV] END ......max_depth=3, max_features=2, n_estimators=100; total time=   0.3s
# [CV] END ......max_depth=3, max_features=2, n_estimators=100; total time=   0.3s
# [CV] END ......max_depth=3, max_features=2, n_estimators=100; total time=   0.3s
# [CV] END ......max_depth=3, max_features=2, n_estimators=200; total time=   0.6s
# [CV] END ......max_depth=3, max_features=2, n_estimators=200; total time=   0.6s
# [CV] END ......max_depth=3, max_features=6, n_estimators=200; total time=   0.6s
# [CV] END ......max_depth=3, max_features=6, n_estimators=200; total time=   0.6s
# [CV] END ......max_depth=3, max_features=6, n_estimators=200; total time=   0.6s
# [CV] END ......max_depth=3, max_features=6, n_estimators=400; total time=   1.2s
# [CV] END ......max_depth=3, max_features=6, n_estimators=400; total time=   1.2s
# [CV] END ......max_depth=3, max_features=6, n_estimators=100; total time=   0.3s
# [CV] END ......max_depth=3, max_features=6, n_estimators=100; total time=   0.3s
# [CV] END ......max_depth=3, max_features=6, n_estimators=100; total time=   0.3s
# [CV] END ......max_depth=3, max_features=6, n_estimators=100; total time=   0.3s
# [CV] END ccp_alpha=0.0031665160658770897, max_depth=3, max_features=3; total time=   0.0s
# [CV] END ccp_alpha=0.0031665160658770897, max_depth=3, max_features=3; total time=   0.0s
# [CV] END ccp_alpha=0.0015382794935510583, max_depth=3, max_features=1; total time=   0.0s
# [CV] END ccp_alpha=0.0015382794935510583, max_depth=3, max_features=1; total time=   0.0s
# [CV] END .........ccp_alpha=0.0, max_depth=3, max_features=4; total time=   0.0s
# [CV] END .........ccp_alpha=0.0, max_depth=3, max_features=4; total time=   0.0s
# [CV] END ccp_alpha=0.17475324433288492, max_depth=3, max_features=4; total time=   0.0s
# [CV] END ccp_alpha=0.17475324433288492, max_depth=3, max_features=4; total time=   0.0s
# [CV] END ccp_alpha=0.17475324433288492, max_depth=3, max_features=4; total time=   0.0s
# [CV] END ccp_alpha=0.17475324433288492, max_depth=3, max_features=4; total time=   0.0s
# [CV] END ccp_alpha=0.0062494853595072425, max_depth=3, max_features=4; total time=   0.0s
# [CV] END ccp_alpha=0.0062494853595072425, max_depth=3, max_features=4; total time=   0.0s
# [CV] END ccp_alpha=0.001277955271565496, max_depth=3, max_features=6; total time=   0.0s
# [CV] END ccp_alpha=0.001277955271565496, max_depth=3, max_features=6; total time=   0.0s
# [CV] END ccp_alpha=0.0031665160658770897, max_depth=3, max_features=2; total time=   0.0s
# [CV] END ccp_alpha=0.0031665160658770897, max_depth=3, max_features=2; total time=   0.0s
# [CV] END ccp_alpha=0.0031665160658770897, max_depth=3, max_features=2; total time=   0.0s
# [CV] END ccp_alpha=0.0031665160658770897, max_depth=3, max_features=2; total time=   0.0s
# [CV] END ccp_alpha=0.0031665160658770897, max_depth=3, max_features=2; total time=   0.0s
# [CV] END ccp_alpha=0.0031665160658770897, max_depth=3, max_features=2; total time=   0.0s
# [CV] END ccp_alpha=0.0031665160658770897, max_depth=3, max_features=2; total time=   0.0s
# [CV] END ccp_alpha=0.0031665160658770897, max_depth=3, max_features=2; total time=   0.0s
# [CV] END ccp_alpha=0.0042940818499924045, max_depth=3, max_features=4; total time=   0.0s
# [CV] END ccp_alpha=0.0042940818499924045, max_depth=3, max_features=4; total time=   0.0s
# [CV] END ccp_alpha=0.0042940818499924045, max_depth=3, max_features=4; total time=   0.0s
# [CV] END .......gamma=1, learning_rate=0.1, n_estimators=100; total time=   0.3s
# [CV] END .......gamma=1, learning_rate=0.1, n_estimators=100; total time=   0.3s
# [CV] END ..gamma=0.1, learning_rate=0.001, n_estimators=1000; total time=   3.2s
# [CV] END ..gamma=0.1, learning_rate=0.001, n_estimators=1000; total time=   3.0s
# [CV] END ..gamma=0.1, learning_rate=0.001, n_estimators=1000; total time=   3.0s
# [CV] END .....gamma=1, learning_rate=0.01, n_estimators=1000; total time=   2.8s
# [CV] END .....gamma=1, learning_rate=0.01, n_estimators=1000; total time=   2.8s
# [CV] END ......gamma=0.1, learning_rate=0.1, n_estimators=50; total time=   0.2s
# [CV] END ......gamma=0.1, learning_rate=0.1, n_estimators=50; total time=   0.2s
# [CV] END ......gamma=0.1, learning_rate=0.1, n_estimators=50; total time=   0.2s
# [CV] END ....gamma=0.1, learning_rate=0.1, n_estimators=1000; total time=   2.9s
# [CV] END ....gamma=0.1, learning_rate=0.1, n_estimators=1000; total time=   2.7s
# [CV] END ....gamma=0.1, learning_rate=0.1, n_estimators=1000; total time=   2.7s
# [CV] END Classifier__C=10, Classifier__gamma=0.1, Classifier__kernel=linear; total time=   0.1s
# [CV] END Classifier__C=10, Classifier__gamma=0.1, Classifier__kernel=linear; total time=   0.0s
# [CV] END Classifier__C=1, Classifier__gamma=0.001, Classifier__kernel=linear; total time=   0.0s
# [CV] END Classifier__C=1, Classifier__gamma=0.001, Classifier__kernel=linear; total time=   0.0s
# [CV] END Classifier__C=1, Classifier__gamma=1, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=1, Classifier__gamma=1, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=1, Classifier__gamma=1, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=1, Classifier__gamma=1, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=100, Classifier__gamma=0.001, Classifier__kernel=linear; total time=   0.2s
# [CV] END Classifier__C=100, Classifier__gamma=0.001, Classifier__kernel=linear; total time=   0.2s
# [CV] END Classifier__C=10, Classifier__gamma=1, Classifier__kernel=linear; total time=   0.0s
# [CV] END Classifier__C=10, Classifier__gamma=1, Classifier__kernel=linear; total time=   0.0s
# [CV] END Classifier__C=10, Classifier__gamma=1, Classifier__kernel=linear; total time=   0.0s
# [CV] END Classifier__C=10, Classifier__gamma=1, Classifier__kernel=linear; total time=   0.0s
# [CV] END Classifier__C=100, Classifier__gamma=1, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=100, Classifier__gamma=1, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=10, Classifier__gamma=0.01, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=10, Classifier__gamma=0.01, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=10, Classifier__gamma=0.01, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=10, Classifier__gamma=0.01, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=1000, Classifier__gamma=0.01, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=1000, Classifier__gamma=0.01, Classifier__kernel=rbf; total time=   0.1s
# [CV] END Classifier__C=1000, Classifier__gamma=0.01, Classifier__kernel=rbf; total time=   0.1s
# [CV] END Classifier__C=1000, Classifier__gamma=0.01, Classifier__kernel=rbf; total time=   0.1s
# [CV] END Classifier__C=1000, Classifier__gamma=0.1, Classifier__kernel=rbf; total time=   0.1s
# [CV] END Classifier__C=1000, Classifier__gamma=0.1, Classifier__kernel=rbf; total time=   0.1s
# [CV] END Classifier__C=10, Classifier__gamma=0.01, Classifier__kernel=linear; total time=   0.0s
# [CV] END Classifier__C=10, Classifier__gamma=0.01, Classifier__kernel=linear; total time=   0.0s
# [CV] END ......max_depth=3, max_features=5, n_estimators=200; total time=   0.6s
# [CV] END ......max_depth=3, max_features=5, n_estimators=200; total time=   0.6s
# [CV] END ......max_depth=3, max_features=3, n_estimators=500; total time=   1.4s
# [CV] END ......max_depth=3, max_features=3, n_estimators=500; total time=   1.4s
# [CV] END ......max_depth=3, max_features=3, n_estimators=500; total time=   1.3s
# [CV] END ......max_depth=3, max_features=4, n_estimators=200; total time=   0.6s
# [CV] END ......max_depth=3, max_features=4, n_estimators=200; total time=   0.6s
# [CV] END ......max_depth=3, max_features=4, n_estimators=500; total time=   1.5s
# [CV] END ......max_depth=3, max_features=4, n_estimators=500; total time=   1.4s
# [CV] END ......max_depth=3, max_features=5, n_estimators=300; total time=   0.9s
# [CV] END ......max_depth=3, max_features=5, n_estimators=300; total time=   0.9s
# [CV] END ......max_depth=3, max_features=5, n_estimators=300; total time=   1.3s
# [CV] END ......max_depth=3, max_features=2, n_estimators=100; total time=   0.5s
# [CV] END ......max_depth=3, max_features=2, n_estimators=100; total time=   0.3s
# [CV] END ......max_depth=3, max_features=2, n_estimators=100; total time=   0.3s
# [CV] END ......max_depth=3, max_features=2, n_estimators=200; total time=   0.6s
# [CV] END ......max_depth=3, max_features=2, n_estimators=200; total time=   0.6s
# [CV] END ......max_depth=3, max_features=6, n_estimators=200; total time=   0.6s
# [CV] END ......max_depth=3, max_features=6, n_estimators=200; total time=   0.6s
# [CV] END ......max_depth=3, max_features=6, n_estimators=200; total time=   0.6s
# [CV] END ......max_depth=3, max_features=6, n_estimators=400; total time=   1.2s
# [CV] END ......max_depth=3, max_features=6, n_estimators=400; total time=   1.2s
# [CV] END ......max_depth=3, max_features=6, n_estimators=100; total time=   0.3s
# [CV] END ......max_depth=3, max_features=6, n_estimators=100; total time=   0.3s
# [CV] END ......max_depth=3, max_features=6, n_estimators=100; total time=   0.3s
# [CV] END ......max_depth=3, max_features=6, n_estimators=100; total time=   0.2s
# [CV] END ccp_alpha=0.0031665160658770897, max_depth=3, max_features=3; total time=   0.0s
# [CV] END ccp_alpha=0.0031665160658770897, max_depth=3, max_features=3; total time=   0.0s
# [CV] END ccp_alpha=0.0015382794935510583, max_depth=3, max_features=1; total time=   0.0s
# [CV] END ccp_alpha=0.0015382794935510583, max_depth=3, max_features=1; total time=   0.0s
# [CV] END .........ccp_alpha=0.0, max_depth=3, max_features=4; total time=   0.0s
# [CV] END .........ccp_alpha=0.0, max_depth=3, max_features=4; total time=   0.0s
# [CV] END ccp_alpha=0.17475324433288492, max_depth=3, max_features=4; total time=   0.0s
# [CV] END ccp_alpha=0.17475324433288492, max_depth=3, max_features=4; total time=   0.0s
# [CV] END ccp_alpha=0.17475324433288492, max_depth=3, max_features=4; total time=   0.0s
# [CV] END ccp_alpha=0.17475324433288492, max_depth=3, max_features=4; total time=   0.0s
# [CV] END ccp_alpha=0.001277955271565496, max_depth=3, max_features=6; total time=   0.0s
# [CV] END ccp_alpha=0.001277955271565496, max_depth=3, max_features=6; total time=   0.0s
# [CV] END ccp_alpha=0.001277955271565496, max_depth=3, max_features=6; total time=   0.0s
# [CV] END ccp_alpha=0.001277955271565496, max_depth=3, max_features=6; total time=   0.0s
# [CV] END ccp_alpha=0.0014376996805111825, max_depth=3, max_features=5; total time=   0.0s
# [CV] END ccp_alpha=0.0014376996805111825, max_depth=3, max_features=5; total time=   0.0s
# [CV] END ccp_alpha=0.0014376996805111825, max_depth=3, max_features=5; total time=   0.0s
# [CV] END ccp_alpha=0.0014376996805111825, max_depth=3, max_features=5; total time=   0.0s
# [CV] END ccp_alpha=0.0014376996805111825, max_depth=3, max_features=5; total time=   0.0s
# [CV] END ccp_alpha=0.0014376996805111825, max_depth=3, max_features=5; total time=   0.0s
# [CV] END ccp_alpha=0.0014376996805111825, max_depth=3, max_features=5; total time=   0.0s
# [CV] END ccp_alpha=0.0014376996805111825, max_depth=3, max_features=5; total time=   0.0s
# [CV] END ccp_alpha=0.0042940818499924045, max_depth=3, max_features=4; total time=   0.0s
# [CV] END .......gamma=1, learning_rate=0.1, n_estimators=100; total time=   0.3s
# [CV] END .......gamma=1, learning_rate=0.1, n_estimators=100; total time=   0.3s
# [CV] END .......gamma=1, learning_rate=0.1, n_estimators=100; total time=   0.3s
# [CV] END ..gamma=0.1, learning_rate=0.001, n_estimators=1000; total time=   3.2s
# [CV] END ..gamma=0.1, learning_rate=0.001, n_estimators=1000; total time=   3.1s
# [CV] END .....gamma=1, learning_rate=0.01, n_estimators=1000; total time=   2.8s
# [CV] END .....gamma=1, learning_rate=0.01, n_estimators=1000; total time=   3.0s
# [CV] END .....gamma=1, learning_rate=0.01, n_estimators=1000; total time=   2.8s
# [CV] END ......gamma=0.1, learning_rate=0.1, n_estimators=50; total time=   0.2s
# [CV] END ....gamma=0.1, learning_rate=0.1, n_estimators=1000; total time=   3.3s
# [CV] END ....gamma=0.1, learning_rate=0.1, n_estimators=1000; total time=   2.7s
# [CV] END ....gamma=0.1, learning_rate=0.1, n_estimators=1000; total time=   2.9s
# [CV] END ......gamma=1, learning_rate=0.1, n_estimators=1000; total time=   2.6s
# [CV] END ......gamma=1, learning_rate=0.1, n_estimators=1000; total time=   2.7s
# [CV] END ..gamma=0.001, learning_rate=0.01, n_estimators=100; total time=   0.3s
# [CV] END ..gamma=0.001, learning_rate=0.01, n_estimators=100; total time=   0.3s
# [CV] END ..gamma=0.001, learning_rate=0.01, n_estimators=100; total time=   0.3s
# [CV] END Classifier__C=10, Classifier__gamma=0.1, Classifier__kernel=linear; total time=   0.0s
# [CV] END Classifier__C=1, Classifier__gamma=0.001, Classifier__kernel=linear; total time=   0.0s
# [CV] END Classifier__C=1, Classifier__gamma=0.001, Classifier__kernel=linear; total time=   0.0s
# [CV] END Classifier__C=1, Classifier__gamma=0.001, Classifier__kernel=linear; total time=   0.0s
# [CV] END Classifier__C=1, Classifier__gamma=1, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=1, Classifier__gamma=1, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=100, Classifier__gamma=0.001, Classifier__kernel=linear; total time=   0.2s
# [CV] END Classifier__C=100, Classifier__gamma=0.001, Classifier__kernel=linear; total time=   0.3s
# [CV] END Classifier__C=10, Classifier__gamma=1, Classifier__kernel=linear; total time=   0.0s
# [CV] END Classifier__C=10, Classifier__gamma=1, Classifier__kernel=linear; total time=   0.0s
# [CV] END Classifier__C=10, Classifier__gamma=1, Classifier__kernel=linear; total time=   0.0s
# [CV] END Classifier__C=10, Classifier__gamma=1, Classifier__kernel=linear; total time=   0.0s
# [CV] END Classifier__C=10, Classifier__gamma=0.01, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=10, Classifier__gamma=0.01, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=10, Classifier__gamma=0.01, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=10, Classifier__gamma=0.01, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=10, Classifier__gamma=0.01, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=10, Classifier__gamma=0.01, Classifier__kernel=rbf; total time=   0.0s
# [CV] END Classifier__C=1000, Classifier__gamma=0.01, Classifier__kernel=rbf; total time=   0.1s
# [CV] END Classifier__C=1000, Classifier__gamma=0.01, Classifier__kernel=rbf; total time=   0.1s
# [CV] END Classifier__C=1000, Classifier__gamma=0.1, Classifier__kernel=rbf; total time=   0.1s
# [CV] END Classifier__C=1000, Classifier__gamma=0.1, Classifier__kernel=rbf; total time=   0.1s
# [CV] END Classifier__C=1000, Classifier__gamma=0.1, Classifier__kernel=rbf; total time=   0.1s
# [CV] END Classifier__C=1000, Classifier__gamma=0.1, Classifier__kernel=rbf; total time=   0.1s
# [CV] END ......max_depth=3, max_features=5, n_estimators=200; total time=   0.6s
# [CV] END ......max_depth=3, max_features=5, n_estimators=200; total time=   0.6s
# [CV] END ......max_depth=3, max_features=5, n_estimators=200; total time=   0.6s
# [CV] END ......max_depth=3, max_features=3, n_estimators=500; total time=   1.4s
# [CV] END ......max_depth=3, max_features=3, n_estimators=500; total time=   1.4s
# [CV] END ......max_depth=3, max_features=4, n_estimators=200; total time=   0.6s
# [CV] END ......max_depth=3, max_features=4, n_estimators=200; total time=   0.6s
# [CV] END ......max_depth=3, max_features=4, n_estimators=200; total time=   0.6s
# [CV] END ......max_depth=3, max_features=4, n_estimators=500; total time=   1.5s
# [CV] END ......max_depth=3, max_features=4, n_estimators=500; total time=   1.5s
# [CV] END ......max_depth=3, max_features=4, n_estimators=500; total time=   1.4s
# [CV] END ......max_depth=3, max_features=5, n_estimators=300; total time=   1.1s
# [CV] END ......max_depth=3, max_features=5, n_estimators=300; total time=   1.3s
# [CV] END ......max_depth=3, max_features=2, n_estimators=100; total time=   0.3s
# [CV] END ......max_depth=3, max_features=2, n_estimators=200; total time=   0.5s
# [CV] END ......max_depth=3, max_features=2, n_estimators=200; total time=   0.5s
# [CV] END ......max_depth=3, max_features=2, n_estimators=200; total time=   0.5s
# [CV] END ......max_depth=3, max_features=6, n_estimators=200; total time=   0.6s
# [CV] END ......max_depth=3, max_features=6, n_estimators=200; total time=   0.6s
# [CV] END ......max_depth=3, max_features=6, n_estimators=400; total time=   1.1s
# [CV] END ......max_depth=3, max_features=6, n_estimators=400; total time=   1.2s
# [CV] END ......max_depth=3, max_features=6, n_estimators=400; total time=   1.1s
# [CV] END ......max_depth=3, max_features=6, n_estimators=100; total time=   0.3s
# [CV] END ccp_alpha=0.0031665160658770897, max_depth=3, max_features=3; total time=   0.0s
# [CV] END ccp_alpha=0.0031665160658770897, max_depth=3, max_features=3; total time=   0.0s
# [CV] END ccp_alpha=0.0015382794935510583, max_depth=3, max_features=1; total time=   0.0s
# [CV] END ccp_alpha=0.0015382794935510583, max_depth=3, max_features=1; total time=   0.0s
# [CV] END ccp_alpha=0.0015382794935510583, max_depth=3, max_features=1; total time=   0.0s
# [CV] END ccp_alpha=0.0015382794935510583, max_depth=3, max_features=1; total time=   0.0s
# [CV] END .........ccp_alpha=0.0, max_depth=3, max_features=4; total time=   0.0s
# [CV] END .........ccp_alpha=0.0, max_depth=3, max_features=4; total time=   0.0s
# [CV] END .........ccp_alpha=0.0, max_depth=3, max_features=4; total time=   0.0s
# [CV] END .........ccp_alpha=0.0, max_depth=3, max_features=4; total time=   0.0s
# [CV] END ccp_alpha=0.0062494853595072425, max_depth=3, max_features=4; total time=   0.0s
# [CV] END ccp_alpha=0.0062494853595072425, max_depth=3, max_features=4; total time=   0.0s
# [CV] END ccp_alpha=0.0062494853595072425, max_depth=3, max_features=4; total time=   0.0s
# [CV] END ccp_alpha=0.0062494853595072425, max_depth=3, max_features=4; total time=   0.0s
# [CV] END ccp_alpha=0.0042940818499924045, max_depth=3, max_features=1; total time=   0.0s
# [CV] END ccp_alpha=0.0042940818499924045, max_depth=3, max_features=1; total time=   0.0s
# [CV] END ccp_alpha=0.0042940818499924045, max_depth=3, max_features=1; total time=   0.0s
# [CV] END ccp_alpha=0.0042940818499924045, max_depth=3, max_features=1; total time=   0.0s
# [CV] END ccp_alpha=0.0042940818499924045, max_depth=3, max_features=1; total time=   0.0s
# [CV] END ccp_alpha=0.0042940818499924045, max_depth=3, max_features=1; total time=   0.0s
# [CV] END ccp_alpha=0.0031665160658770897, max_depth=3, max_features=2; total time=   0.0s
# [CV] END ccp_alpha=0.0031665160658770897, max_depth=3, max_features=2; total time=   0.0s
# [CV] END ccp_alpha=0.0014376996805111825, max_depth=3, max_features=5; total time=   0.0s
# [CV] END ccp_alpha=0.0042940818499924045, max_depth=3, max_features=4; total time=   0.0s
# [CV] END ccp_alpha=0.0042940818499924045, max_depth=3, max_features=4; total time=   0.0s
# [CV] END .......gamma=1, learning_rate=0.1, n_estimators=100; total time=   0.3s
# [CV] END .......gamma=1, learning_rate=0.1, n_estimators=100; total time=   0.3s
# [CV] END .......gamma=1, learning_rate=0.1, n_estimators=100; total time=   0.3s
# [CV] END ..gamma=0.1, learning_rate=0.001, n_estimators=1000; total time=   3.2s
# [CV] END ..gamma=0.1, learning_rate=0.001, n_estimators=1000; total time=   3.1s
# [CV] END .....gamma=1, learning_rate=0.01, n_estimators=1000; total time=   2.7s
# [CV] END .....gamma=1, learning_rate=0.01, n_estimators=1000; total time=   3.0s
# [CV] END .....gamma=1, learning_rate=0.01, n_estimators=1000; total time=   2.8s
# [CV] END ......gamma=0.1, learning_rate=0.1, n_estimators=50; total time=   0.2s
# [CV] END ......gamma=0.1, learning_rate=0.1, n_estimators=50; total time=   0.2s
# [CV] END ....gamma=0.1, learning_rate=0.1, n_estimators=1000; total time=   3.4s
# [CV] END ....gamma=0.1, learning_rate=0.1, n_estimators=1000; total time=   2.8s
# [CV] END ......gamma=1, learning_rate=0.1, n_estimators=1000; total time=   2.7s
# [CV] END ......gamma=1, learning_rate=0.1, n_estimators=1000; total time=   2.9s
# [CV] END ......gamma=1, learning_rate=0.1, n_estimators=1000; total time=   2.5s
# [CV] END ..gamma=0.001, learning_rate=0.01, n_estimators=100; total time=   0.3s
# [CV] END ..gamma=0.001, learning_rate=0.01, n_estimators=100; total time=   0.3s
# [CV] END ........gamma=1, learning_rate=1, n_estimators=1000; total time=   2.8s
# [CV] END ........gamma=1, learning_rate=1, n_estimators=1000; total time=   2.7s
# [CV] END ......gamma=0.01, learning_rate=1, n_estimators=100; total time=   0.3s
# [CV] END ......gamma=0.01, learning_rate=1, n_estimators=100; total time=   0.3s
# [CV] END ......gamma=0.01, learning_rate=1, n_estimators=100; total time=   0.3s
# Best parameters for XGB model:  {'n_estimators': 100, 'learning_rate': 1, 'gamma': 0.01}

# %%
# Best parameters
xg_best = pd.DataFrame.from_dict(xg_model.best_params_, orient = "index").rename(columns = {0: "Best"})
xg_best
# Out:
#                  Best
# n_estimators   100.00
# learning_rate    1.00
# gamma            0.01

# %% [markdown]
# ##### **4.5.2.Building model with best parameters**

# %%
xg_clf = XGBClassifier(n_estimators = int(xg_best.iloc[0,0]), 
                       learning_rate = float(xg_best.iloc[1,0]),
                       gamma = float(xg_best.iloc[2,0]),
                       random_state = seed)
# Fit the model
xg_clf.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=0.01, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=1.0, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               objective='multi:softprob', predictor=None, ...)

# %% [markdown]
# ##### **4.5.3.Predictions and model accuracy**

# %%
xg_pred = xg_clf.predict(X_test)
xg_acc = accuracy_score(y_test, xg_pred)
print("XGB Model Accuracy:", xg_acc)
xg_acc_tr = xg_clf.score(X_train, y_train)
print("XGB Training Accuracy:", xg_acc_tr)
# Out:
# XGB Model Accuracy: 0.862453531598513
# XGB Training Accuracy: 0.9424920127795527

# %% [markdown]
# ##### **4.5.4.Other test parameters**

# %%
# Classification Report
print("XGB Classification Report\n\n", classification_report(y_test, xg_pred))
# Out:
# XGB Classification Report
#
#                precision    recall  f1-score   support
#
#            0       0.89      0.83      0.86       100
#            1       0.78      0.85      0.81        87
#            2       0.93      0.91      0.92        82
#
#     accuracy                           0.86       269
#    macro avg       0.87      0.87      0.86       269
# weighted avg       0.87      0.86      0.86       269

# %%
# For comparison list records
xg_recall = recall_score(y_test, xg_pred, average = None)
xg_prec = precision_score(y_test, xg_pred, average = None)
xg_f1 = f1_score(y_test, xg_pred, average = None)

# %%
# Confusion matrix
xg_cm = confusion_matrix(y_test, xg_pred, labels = xg_clf.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix = xg_cm,
                              display_labels = xg_clf.classes_)
print("XGB Confusion Matrix")
disp.plot()
plt.show();
# Out:
# XGB Confusion Matrix

# %%
# Prediction rates
calculatePredictionRates("XGB", xg_acc, xg_cm)
# Out:
#     The success rate of the XGB model on the test set: 86%
#     Low risk correct prediction rate: 83%
#     Mid risk correct prediction rate: 85%
#     High risk correct prediction rate: 86%

# %%
# Train/Test Performance Metrics
xg_pm = pd.DataFrame(calculatePerformance(xg_clf, X_train, y_train, X_test, y_test))*100
xg_pm
# Out:
# Model Performance Metrics Comparison
#    Train Accuracy  Test Accuracy  Train Recall  Test Recall  Train Precision  \
# 0       94.249201      86.245353     90.987124    83.000000        94.222222
# 1       94.249201      86.245353     94.088670    85.057471        89.671362
# 2       94.249201      86.245353     98.421053    91.463415        99.468085
#
#    Test Precision   Train F1    Test F1
# 0       89.247312  92.576419  86.010363
# 1       77.894737  91.826923  81.318681
# 2       92.592593  98.941799  92.024540

# %%
# Updating comparison lists
updateLists("XGB", xg_clf, xg_pred, xg_acc, xg_cm, xg_f1, xg_pm, xg_prec, xg_recall, xg_acc_tr)

# %% [markdown]
# ##### **4.5.5.Feature Importances**

# %%
# Ploting the impurity-based feature importances
feats = {} # a dictionary to hold feature_name: feature_importance
importances = xg_clf.feature_importances_
xg_clf.feature_importances_
# Out:
# array([0.04928481, 0.24748757, 0.04733478, 0.22539206, 0.38570827,
#        0.04479256], dtype=float32)

# %%
for feature, importance in zip(X.columns, xg_clf.feature_importances_):
    feats[feature] = importance #add the name/value pair 
importances = pd.DataFrame.from_dict(feats, orient = "index").rename(columns = {0: "Gini-importance"})
importances = importances.sort_values(by = "Gini-importance")
importances.plot.barh();

# %% [markdown]
# #### **4.6.Deep Learning Model**

# %% [markdown]
# ##### **4.6.1.Building the model**

# %%
# Model creation
dl_clf = keras.Sequential()
# Layers
dl_clf.add(layers.Dense(128, activation = "relu", input_shape = (X_trainStandart.shape[1], ) ))
dl_clf.add(layers.Dense(64, activation = "relu"))
dl_clf.add(layers.Dense(3, activation = "softmax"))
# Compile
dl_clf.compile(optimizer = "adam", loss = "sparse_categorical_crossentropy", metrics = ["accuracy"])
# Training
dl_hist = dl_clf.fit(X_trainStandart, 
                     y_train, 
                     validation_data = (X_testStandart, y_test),
                     epochs = 100)
# Out:
# Epoch 1/100
# 20/20 [==============================] - 1s 17ms/step - loss: 0.9809 - accuracy: 0.5639 - val_loss: 0.8117 - val_accuracy: 0.6989
# Epoch 2/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.7341 - accuracy: 0.6853 - val_loss: 0.6672 - val_accuracy: 0.6914
# Epoch 3/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.6298 - accuracy: 0.7077 - val_loss: 0.6072 - val_accuracy: 0.6952
# Epoch 4/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5806 - accuracy: 0.7157 - val_loss: 0.5763 - val_accuracy: 0.7212
# Epoch 5/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5564 - accuracy: 0.7284 - val_loss: 0.5569 - val_accuracy: 0.7063
# Epoch 6/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5352 - accuracy: 0.7332 - val_loss: 0.5469 - val_accuracy: 0.6914
# Epoch 7/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5240 - accuracy: 0.7444 - val_loss: 0.5379 - val_accuracy: 0.7138
# Epoch 8/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5074 - accuracy: 0.7524 - val_loss: 0.5307 - val_accuracy: 0.7435
# Epoch 9/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.4987 - accuracy: 0.7476 - val_loss: 0.5285 - val_accuracy: 0.7212
# Epoch 10/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4927 - accuracy: 0.7572 - val_loss: 0.5211 - val_accuracy: 0.7286
# Epoch 11/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4840 - accuracy: 0.7636 - val_loss: 0.5186 - val_accuracy: 0.7323
# Epoch 12/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.4804 - accuracy: 0.7652 - val_loss: 0.5175 - val_accuracy: 0.7398
# Epoch 13/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4799 - accuracy: 0.7716 - val_loss: 0.5115 - val_accuracy: 0.7286
# Epoch 14/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4718 - accuracy: 0.7780 - val_loss: 0.5108 - val_accuracy: 0.7212
# Epoch 15/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.4648 - accuracy: 0.7859 - val_loss: 0.5036 - val_accuracy: 0.7398
# Epoch 16/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4612 - accuracy: 0.7859 - val_loss: 0.5015 - val_accuracy: 0.7398
# Epoch 17/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.4565 - accuracy: 0.7971 - val_loss: 0.4999 - val_accuracy: 0.7472
# Epoch 18/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.4502 - accuracy: 0.7907 - val_loss: 0.4982 - val_accuracy: 0.7472
# Epoch 19/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4474 - accuracy: 0.7812 - val_loss: 0.4971 - val_accuracy: 0.7509
# Epoch 20/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4446 - accuracy: 0.7939 - val_loss: 0.4939 - val_accuracy: 0.7361
# Epoch 21/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4394 - accuracy: 0.8003 - val_loss: 0.4876 - val_accuracy: 0.7509
# Epoch 22/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.4398 - accuracy: 0.8019 - val_loss: 0.4926 - val_accuracy: 0.7472
# Epoch 23/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4328 - accuracy: 0.8035 - val_loss: 0.4865 - val_accuracy: 0.7509
# Epoch 24/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4313 - accuracy: 0.7907 - val_loss: 0.4841 - val_accuracy: 0.7472
# Epoch 25/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4308 - accuracy: 0.8003 - val_loss: 0.4849 - val_accuracy: 0.7509
# Epoch 26/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4376 - accuracy: 0.7987 - val_loss: 0.4876 - val_accuracy: 0.7472
# Epoch 27/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4262 - accuracy: 0.8067 - val_loss: 0.4805 - val_accuracy: 0.7584
# Epoch 28/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4252 - accuracy: 0.8067 - val_loss: 0.4815 - val_accuracy: 0.7546
# Epoch 29/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4227 - accuracy: 0.7971 - val_loss: 0.4819 - val_accuracy: 0.7621
# Epoch 30/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4205 - accuracy: 0.8147 - val_loss: 0.4795 - val_accuracy: 0.7546
# Epoch 31/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.4136 - accuracy: 0.8163 - val_loss: 0.4800 - val_accuracy: 0.7621
# Epoch 32/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.4142 - accuracy: 0.8083 - val_loss: 0.4781 - val_accuracy: 0.7695
# Epoch 33/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4141 - accuracy: 0.8147 - val_loss: 0.4735 - val_accuracy: 0.7658
# Epoch 34/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4126 - accuracy: 0.8083 - val_loss: 0.4800 - val_accuracy: 0.7695
# Epoch 35/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4106 - accuracy: 0.8179 - val_loss: 0.4739 - val_accuracy: 0.7695
# Epoch 36/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4093 - accuracy: 0.8147 - val_loss: 0.4766 - val_accuracy: 0.7584
# Epoch 37/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4015 - accuracy: 0.8227 - val_loss: 0.4690 - val_accuracy: 0.7844
# Epoch 38/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4047 - accuracy: 0.8147 - val_loss: 0.4677 - val_accuracy: 0.7658
# Epoch 39/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3982 - accuracy: 0.8259 - val_loss: 0.4687 - val_accuracy: 0.7807
# Epoch 40/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3998 - accuracy: 0.8243 - val_loss: 0.4718 - val_accuracy: 0.7807
# Epoch 41/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3945 - accuracy: 0.8275 - val_loss: 0.4753 - val_accuracy: 0.7770
# Epoch 42/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3944 - accuracy: 0.8211 - val_loss: 0.4625 - val_accuracy: 0.7881
# Epoch 43/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3934 - accuracy: 0.8307 - val_loss: 0.4631 - val_accuracy: 0.7807
# Epoch 44/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3886 - accuracy: 0.8307 - val_loss: 0.4655 - val_accuracy: 0.7807
# Epoch 45/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3913 - accuracy: 0.8243 - val_loss: 0.4730 - val_accuracy: 0.7546
# Epoch 46/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3890 - accuracy: 0.8291 - val_loss: 0.4591 - val_accuracy: 0.7732
# Epoch 47/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3849 - accuracy: 0.8275 - val_loss: 0.4621 - val_accuracy: 0.7844
# Epoch 48/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3899 - accuracy: 0.8403 - val_loss: 0.4685 - val_accuracy: 0.7807
# Epoch 49/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3854 - accuracy: 0.8323 - val_loss: 0.4559 - val_accuracy: 0.7658
# Epoch 50/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3793 - accuracy: 0.8355 - val_loss: 0.4642 - val_accuracy: 0.7918
# Epoch 51/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3790 - accuracy: 0.8419 - val_loss: 0.4593 - val_accuracy: 0.7881
# Epoch 52/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3791 - accuracy: 0.8355 - val_loss: 0.4546 - val_accuracy: 0.7844
# Epoch 53/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3755 - accuracy: 0.8419 - val_loss: 0.4642 - val_accuracy: 0.7844
# Epoch 54/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3763 - accuracy: 0.8403 - val_loss: 0.4569 - val_accuracy: 0.7993
# Epoch 55/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3712 - accuracy: 0.8371 - val_loss: 0.4591 - val_accuracy: 0.7881
# Epoch 56/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3720 - accuracy: 0.8450 - val_loss: 0.4673 - val_accuracy: 0.7807
# Epoch 57/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3741 - accuracy: 0.8514 - val_loss: 0.4583 - val_accuracy: 0.7844
# Epoch 58/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3710 - accuracy: 0.8435 - val_loss: 0.4578 - val_accuracy: 0.7955
# Epoch 59/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3666 - accuracy: 0.8466 - val_loss: 0.4637 - val_accuracy: 0.7918
# Epoch 60/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3745 - accuracy: 0.8419 - val_loss: 0.4770 - val_accuracy: 0.7844
# Epoch 61/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3723 - accuracy: 0.8275 - val_loss: 0.4639 - val_accuracy: 0.7844
# Epoch 62/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3712 - accuracy: 0.8419 - val_loss: 0.4661 - val_accuracy: 0.7993
# Epoch 63/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3657 - accuracy: 0.8371 - val_loss: 0.4548 - val_accuracy: 0.7770
# Epoch 64/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3664 - accuracy: 0.8371 - val_loss: 0.4626 - val_accuracy: 0.7881
# Epoch 65/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3642 - accuracy: 0.8482 - val_loss: 0.4548 - val_accuracy: 0.7881
# Epoch 66/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3569 - accuracy: 0.8466 - val_loss: 0.4581 - val_accuracy: 0.7732
# Epoch 67/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3546 - accuracy: 0.8546 - val_loss: 0.4537 - val_accuracy: 0.7993
# Epoch 68/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3525 - accuracy: 0.8482 - val_loss: 0.4525 - val_accuracy: 0.7844
# Epoch 69/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3568 - accuracy: 0.8450 - val_loss: 0.4546 - val_accuracy: 0.7993
# Epoch 70/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3525 - accuracy: 0.8562 - val_loss: 0.4560 - val_accuracy: 0.8030
# Epoch 71/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3518 - accuracy: 0.8514 - val_loss: 0.4625 - val_accuracy: 0.7844
# Epoch 72/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3501 - accuracy: 0.8578 - val_loss: 0.4729 - val_accuracy: 0.7993
# Epoch 73/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3488 - accuracy: 0.8482 - val_loss: 0.4620 - val_accuracy: 0.7918
# Epoch 74/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3489 - accuracy: 0.8482 - val_loss: 0.4583 - val_accuracy: 0.8030
# Epoch 75/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3471 - accuracy: 0.8626 - val_loss: 0.4513 - val_accuracy: 0.7918
# Epoch 76/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3506 - accuracy: 0.8530 - val_loss: 0.4566 - val_accuracy: 0.7918
# Epoch 77/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3510 - accuracy: 0.8514 - val_loss: 0.4645 - val_accuracy: 0.7807
# Epoch 78/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3500 - accuracy: 0.8546 - val_loss: 0.4536 - val_accuracy: 0.7993
# Epoch 79/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3441 - accuracy: 0.8546 - val_loss: 0.4479 - val_accuracy: 0.7881
# Epoch 80/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3438 - accuracy: 0.8594 - val_loss: 0.4577 - val_accuracy: 0.7918
# Epoch 81/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3402 - accuracy: 0.8610 - val_loss: 0.4520 - val_accuracy: 0.7955
# Epoch 82/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3422 - accuracy: 0.8498 - val_loss: 0.4611 - val_accuracy: 0.8067
# Epoch 83/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3376 - accuracy: 0.8674 - val_loss: 0.4589 - val_accuracy: 0.8104
# Epoch 84/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3374 - accuracy: 0.8594 - val_loss: 0.4564 - val_accuracy: 0.8067
# Epoch 85/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3417 - accuracy: 0.8626 - val_loss: 0.4606 - val_accuracy: 0.7993
# Epoch 86/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3346 - accuracy: 0.8514 - val_loss: 0.4627 - val_accuracy: 0.8067
# Epoch 87/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3369 - accuracy: 0.8610 - val_loss: 0.4595 - val_accuracy: 0.7993
# Epoch 88/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3349 - accuracy: 0.8546 - val_loss: 0.4560 - val_accuracy: 0.7918
# Epoch 89/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3361 - accuracy: 0.8546 - val_loss: 0.4486 - val_accuracy: 0.7918
# Epoch 90/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3293 - accuracy: 0.8594 - val_loss: 0.4547 - val_accuracy: 0.8104
# Epoch 91/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3313 - accuracy: 0.8610 - val_loss: 0.4532 - val_accuracy: 0.7955
# Epoch 92/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3224 - accuracy: 0.8610 - val_loss: 0.4536 - val_accuracy: 0.7993
# Epoch 93/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3248 - accuracy: 0.8642 - val_loss: 0.4599 - val_accuracy: 0.8067
# Epoch 94/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3246 - accuracy: 0.8594 - val_loss: 0.4575 - val_accuracy: 0.8030
# Epoch 95/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3240 - accuracy: 0.8594 - val_loss: 0.4560 - val_accuracy: 0.7918
# Epoch 96/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3203 - accuracy: 0.8658 - val_loss: 0.4467 - val_accuracy: 0.8067
# Epoch 97/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3267 - accuracy: 0.8578 - val_loss: 0.4552 - val_accuracy: 0.8030
# Epoch 98/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3226 - accuracy: 0.8706 - val_loss: 0.4665 - val_accuracy: 0.8104
# Epoch 99/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3204 - accuracy: 0.8658 - val_loss: 0.4514 - val_accuracy: 0.8067
# Epoch 100/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3232 - accuracy: 0.8498 - val_loss: 0.4536 - val_accuracy: 0.8030

# %% [markdown]
# ##### **4.6.2.Predictions and model accuracy**

# %%
dl_pred_proba = dl_clf.predict(X_testStandart) #probabilities
dl_pred = (dl_pred_proba > 0.5).astype("int") #one-hot encoded
dl_acc = dl_clf.evaluate(X_testStandart, y_test)[1]
print("Deep Learning Model Accuracy:", dl_acc)
dl_acc_tr = dl_clf.evaluate(X_trainStandart, y_train)[1]
print("Deep Learning Training Accuracy:", dl_acc_tr)
# Out:
# 9/9 [==============================] - 0s 2ms/step
# 9/9 [==============================] - 0s 2ms/step - loss: 0.4536 - accuracy: 0.8030
# Deep Learning Model Accuracy: 0.8029739856719971
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3065 - accuracy: 0.8722
# Deep Learning Training Accuracy: 0.8722044825553894

# %% [markdown]
# ##### **4.6.3.Other test parameters**

# %%
# Model metrics history
plt.plot(dl_hist.history['accuracy'])
plt.plot(dl_hist.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['train', 'test'], loc = 'center right')
plt.rcParams['figure.dpi'] = 300
plt.show()
        
plt.plot(dl_hist.history['loss'])
plt.plot(dl_hist.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'test'], loc = 'center right')
plt.rcParams['figure.dpi'] = 300
plt.show()

# %%
# For getting classification parameters we have to convert one-hot encoded dl_pred to single-digits
dl_pred_arg = np.argmax(dl_clf.predict(X_testStandart), axis = 1)
# Out:
# 9/9 [==============================] - 0s 2ms/step

# %%
# Classification Report
print("Deep Learning Classification Report\n\n", classification_report(y_test, dl_pred_arg))
# Out:
# Deep Learning Classification Report
#
#                precision    recall  f1-score   support
#
#            0       0.78      0.83      0.80       100
#            1       0.71      0.69      0.70        87
#            2       0.95      0.89      0.92        82
#
#     accuracy                           0.80       269
#    macro avg       0.81      0.80      0.81       269
# weighted avg       0.81      0.80      0.80       269

# %%
# For comparison list recordings
dl_recall = recall_score(y_test, dl_pred_arg, average = None)
dl_prec = precision_score(y_test, dl_pred_arg, average = None)
dl_f1 = f1_score(y_test, dl_pred_arg, average = None)

# %%
# Confusion matrix
dl_cm = confusion_matrix(y_test, dl_pred_arg, labels = np.arange(0,3))
disp = ConfusionMatrixDisplay(confusion_matrix = dl_cm,
                              display_labels = np.arange(0,3))
print("Deep Learning Confusion Matrix")
disp.plot()
plt.show()
# Out:
# Deep Learning Confusion Matrix

# %%
# Prediction rates
calculatePredictionRates("Deep Learning", dl_acc, dl_cm)
# Out:
#     The success rate of the Deep Learning model on the test set: 80%
#     Low risk correct prediction rate: 83%
#     Mid risk correct prediction rate: 69%
#     High risk correct prediction rate: 84%

# %%
# Train/Test Performance Metrics
def calculateDLPerformance(classifier, X_train, y_train, X_test, y_test):
    train_pred = np.argmax(classifier.predict(X_train), axis = 1)
    test_pred = np.argmax(classifier.predict(X_test), axis = 1)
    scores = {
        "Train Accuracy": accuracy_score(y_train, train_pred),
        "Test Accuracy": accuracy_score(y_test, test_pred),
        "Train Recall": recall_score(y_train, train_pred, average = None),
        "Test Recall": recall_score(y_test, test_pred, average = None),
        "Train Precision": precision_score(y_train, train_pred, average = None), 
        "Test Precision": precision_score(y_test, test_pred, average = None), 
        "Train F1": f1_score(y_train, train_pred, average = None),
        "Test F1": f1_score(y_test, test_pred, average = None) 
    }
    print("Model Performance Metrics Comparison")
    return scores

# %%
dl_pm = pd.DataFrame(calculateDLPerformance(dl_clf, X_trainStandart, y_train, X_testStandart, y_test))*100
dl_pm
# Out:
# 20/20 [==============================] - 0s 1ms/step
# 9/9 [==============================] - 0s 1ms/step
# Model Performance Metrics Comparison
#    Train Accuracy  Test Accuracy  Train Recall  Test Recall  Train Precision  \
# 0       87.220447      80.297398     91.416309    83.000000        81.609195
# 1       87.220447      80.297398     78.325123    68.965517        84.126984
# 2       87.220447      80.297398     91.578947    89.024390        98.863636
#
#    Test Precision   Train F1    Test F1
# 0       77.570093  86.234818  80.193237
# 1       70.588235  81.122449  69.767442
# 2       94.805195  95.081967  91.823899

# %%
# Updating comparison lists
updateLists("DeepLearning", dl_clf, dl_pred_arg, dl_acc, dl_cm, dl_f1, dl_pm, dl_prec, dl_recall, dl_acc_tr)

# %% [markdown]
# # **5.Model Comparison**

# %% [markdown]
# #### **5.1.Comparison of all metrics and models**

# %%
def compare_metrics_barplot(comparison_list, model_list, metric_list, color_list):
    size = range(len(model_list))
    color_list = cmap
    w = 0.15    
    
    # Selecting metrics one by one for all models
    def select_metrics(comparison_list, metric_list):
        row_list = []
        for metric in metric_list:
            row_out = list(comparison_list.loc[metric])
            row_list.append(row_out)
        return row_list
    
    y = select_metrics(comparison_list, metric_list)
    
    # Figure size
    plt.figure(figsize = (10, 5))
    # Positions, colors, labels and axes
    for i in range(len(metric_list)):
        plt.bar([pos + (i * w) for pos in size], 
                y[i], 
                width = w, 
                align = "center", 
                label = metric_list[i],
                color = color_list[i]) 
    # Display plot    
    plt.xlabel("Metrics")
    plt.ylabel("Rate")
    plt.title("All Metrics Comparison by Model's Built Order")
    plt.xticks([pos + (1 * w) for pos in size], model_list, rotation = 90)
    plt.yticks(np.arange(0, 105, 5))
    plt.legend(bbox_to_anchor = (1, 1), loc = "best")
    plt.show()

# %%
for p in performs:
    compare_metrics_barplot(p, p.columns.to_list(), p.index.to_list(), cmap)

# %% [markdown]
# #### **5.2.Comparison of models test & training accuracies**

# %%
plt.figure(figsize = (10, 5))

plt.bar(np.arange(len(model_names)) - 0.2, 
        np.array(acc_list)*100, 0.4, label = "Model Accuracy", color = "lightblue") 
plt.bar(np.arange(len(model_names)) + 0.2, 
        np.array(tr_acc_list)*100, 0.4, label = "Training Accuracy", color = "darkred") 
plt.xticks(np.arange(len(model_names)), model_names, rotation = 90)
plt.xlabel("Models")
plt.ylabel("Accuracy")
plt.title("Accuracy Comparison")
plt.yticks(np.arange(0, 105, 5))
plt.legend(bbox_to_anchor = (1, 1), loc = "best")
plt.show()

# %% [markdown]
# #### **5.3.Comparison of confusion matrices**

# %%
title_size = 15
plt.rcParams.update({"font.size": 13})
color_map = "viridis"
colorbar = False

# Subplots
f, axes = plt.subplots(3, 2, figsize = (15, 20))

for i, j in np.ndindex(axes.shape):
    
    if [i, j] == [2, 1]:
        axes[i, j].set_title(model_names[2*i + j], size = title_size)
        disp = ConfusionMatrixDisplay(confusion_matrix = cm_list[2*i + j], 
                                      display_labels = np.arange(0,3))
        disp.plot(include_values = True, cmap = color_map, ax = axes[i, j], colorbar = colorbar)
    else:
        axes[i, j].set_title(model_names[2*i + j], size = title_size)
        disp = ConfusionMatrixDisplay(confusion_matrix = cm_list[2*i + j], 
                                      display_labels = clf_list[2*i + j].classes_)
        disp.plot(include_values = True, cmap = color_map, ax = axes[i, j], colorbar = colorbar)
    
f.suptitle("Confusion Matrices Comparison", size = title_size, y=0.92)
plt.show()

# %% [markdown]
# The XGB model has the best accuracy score on the test set. SVC and Deep Learning models follow in order. The Decision Tree model has the worst accuracy.
#
# As can be seen from the confusion matrices, Random Forest, Decision Tree and Logistic Regression models predict low risk level more correctly. Likewise XGB, SVC and Deep Learning models predict mid risk level more correctly. But since this is a medical data set, the most important predictions for us  are about high risk level. Again XGB, SVC and Deep Learning models predict high risk level more correctly.
#
# So, most balanced and high accurate model seems XGB model for this data set.
